# %%
import pandas_datareader.data as reader

# %%
import pandas as pd
import datetime as dt
from dateutil.relativedelta import relativedelta

# %%
import json
requestBody={
  "userId": "DR33829",
  "password": "54321cms@R",
  "yob": "1988"
}

# %%
import requests
headers = {
  'Content-Type': 'application/json',
  'Accept': 'application/json'
}

r = requests.post('https://api.stocknote.com/login'
, data=json.dumps(requestBody)
, headers = headers)

print (r.json())
# Out:
# {'serverTime': '30/03/21 10:41:39', 'msgId': 'c68f69fa-b4d6-408b-9ff5-a07fd00167d1', 'status': 'Success', 'statusMessage': 'Login session token generated successfully ', 'sessionToken': 'a3f2c8842dfbf9375060d013fbd2271f', 'accountID': 'DR33829', 'accountName': 'RAJNEESH SHARMA', 'exchangeList': ['BSE', 'BFO', 'CDS', 'MCX', 'NSE'], 'orderTypeList': ['MKT', 'L', 'SL'], 'productList': ['MIS', 'CNC', 'NRML']}

# %%
headers = {
  'Accept': 'application/json',
  'x-session-token': 'a3f2c8842dfbf9375060d013fbd2271f'
}

r = requests.get('https://api.stocknote.com/quote/getQuote', params={
  'symbolName': 'INFRATEL'
}, headers = headers)

print (r.json())
# Out:
# {'serverTime': '30/03/21 10:41:55', 'msgId': 'f08997bd-4bc8-454d-be4b-46283b119364', 'status': 'Failure', 'statusMessage': 'No Symbol found for the provided symbol name and exchange.'}

# %%
list1= ['INFY', 'Reliance']
for name in list1:
    print(name)
    #name=[]
    headers = {
      'Accept': 'application/json',
      'x-session-token': 'a3f2c8842dfbf9375060d013fbd2271f'
    }
    name_new = name+ '_year'
    name_new = requests.get('https://api.stocknote.com/history/candleData', params={
      f'symbolName': {name},  'fromDate': '2019-10-11'
    }, headers = headers)
    #name_new = name+ '_data'
    r=name_new.json()
#l_infy= r.json()
# Out:
# INFY
# Reliance

# %%
nifty_50 = ['ADANIPORTS','ASIANPAINT','AXISBANK','BAJAJ-AUTO','BAJFINANCE','BAJAJFINSV','BHARTIARTL',

'BPCL',
'CIPLA',
'COALINDIA',
'DRREDDY',
'EICHERMOT',
'GAIL',
'GRASIM',
'HCLTECH',
'HDFC',
'HDFCBANK',
'HEROMOTOCO',
'HINDALCO',
'HINDUNILVR',
'BRITANNIA',
'ICICIBANK',
'INDUSINDBK',
'INFY',
'IOC',
'ITC',
'JSWSTEEL',
'KOTAKBANK',
'LT',
'M&M',
'MARUTI',
'NESTLEIND',
'NTPC',
'ONGC',
'POWERGRID',
'RELIANCE',
'SBIN',
'SUNPHARMA',
'TCS',
'TATAMOTORS',
'TATASTEEL',
'TECHM',
'TITAN',
'ULTRACEMCO',
'UPL',
'VEDL',
'WIPRO',
'SHREECEM',
'ZEEL']

# %%
# These are all the keys you want
key_names= nifty_50 
#key_names=['AXISBANK','BAJAJ-AUTO','BAJFINANCE']
'''['ADANIPORTS','ASIANPAINT','AXISBANK','BAJAJ-AUTO','BAJFINANCE','BAJAJFINSV','BHARTIARTL',
'INFRATEL',
'BPCL',
'CIPLA',
'COALINDIA',
'DRREDDY',
'EICHERMOT',
'GAIL',
'GRASIM',
'HCLTECH',
'HDFC',
'HDFCBANK',
'HEROMOTOCO',
'HINDALCO',
'HINDUNILVR',
'BRITANNIA',
'ICICIBANK',
'INDUSINDBK',
'INFY',
'IOC',
'ITC',
'JSWSTEEL',
'KOTAKBANK',
'LT',
'M&M',
'MARUTI',
'NESTLEIND',
'NTPC',
'ONGC',
'POWERGRID',
'RELIANCE',
'SBIN',
'SUNPHARMA',
'TCS',
'TATAMOTORS',
'TATASTEEL',
'TECHM',
'TITAN',
'ULTRACEMCO',
'UPL',
'VEDL',
'WIPRO',
'SHREECEM',
'ZEEL']'''

# Holds the data you want to pass to the dataframe.
df_info = pd.DataFrame()


#for group_name in Groups:
headers = {
      'Accept': 'application/json',
      'x-session-token':            'a3f2c8842dfbf9375060d013fbd2271f'
    }
# For each group in the groups, we iterate over all the keys we want.
for key in key_names[:1]:
#    headers = {
#      'Accept': 'application/json',
#     'x-session-token':            'a3f2c8842dfbf9375060d013fbd2271f'
#    }

    # Generate a keyname that you want for your dataframe.
    avg_key_name = key 
    print(avg_key_name)
    #std_key_name = key + '_Standard_Dev'
    smaUsed=[50,150,200]
    
    
    
    if avg_key_name not in df_info:
        df_info[avg_key_name] = 0
        #df_info[std_key_name] = []
        
    name = requests.get('https://api.stocknote.com/history/candleData', params={
      f'symbolName': {avg_key_name},  'fromDate': '2019-10-11'
    }, headers = headers)
    
    r=name.json()
    print(r)
    date1=[]
    ltp=[]
    for i in range(len(r['historicalCandleData'])):
        date1.append(r['historicalCandleData'][i]['date'])
        ltp.append(r['historicalCandleData'][i]['ltp'])
    df_info[avg_key_name]=ltp
    date1=date1
    #print(ltp)
    #df_info[std_key_name].append()
    #print(ltp)
#df_info= df_info.append(date1,axis=1)
#df_info = pd.DataFrame(df_info, index=date1)
#df_dates = df.index
df_info['date1'] = date1
#df_info['date1'] = pd.to_datetime(df['date'])
#df_info = df_info.set_index('date1')
# Out:
# ADANIPORTS
# ...

# %%
df_info
# Out:
#     ADANIPORTS ASIANPAINT AXISBANK BAJAJ-AUTO BAJFINANCE BAJAJFINSV  \
# 0        405.8    1772.25    672.1     2779.5     3959.9    8142.55
# 1        402.6    1780.75    684.0     2830.0     3858.0     8065.0
# 2       410.35    1788.75    689.9     2890.6     3874.3     8045.0
# 3        405.8    1752.15   692.65     2902.0     4015.0     8146.0
# 4       404.75    1795.65   710.35     3018.0     4086.0    8311.65
# ..         ...        ...      ...        ...        ...        ...
# 354      686.0     2426.0   724.75    3558.15     5357.5     9491.0
# 355      680.9     2410.0   718.35    3674.55     5393.4     9445.0
# 356      688.0     2411.0    725.2     3645.8     5446.5     9420.9
# 357     721.95    2427.95    717.0     3661.5     5384.1     9402.0
# 358     736.75     2410.0   730.95     3667.0     5376.0     9425.0
#
#     BHARTIARTL    BPCL   CIPLA COALINDIA  ... TATASTEEL   TECHM    TITAN  \
# 0       382.45   454.6  438.05     164.5  ...     328.6   691.0   1238.0
# ...

# %%
df_info=df_info.set_index(['date1'])

# %%
df_info1 = (pd.to_datetime(df_info.index))

# %%
df_info1
# Out:
# DatetimeIndex(['2019-10-11', '2019-10-14', '2019-10-15', '2019-10-16',
#                '2019-10-17', '2019-10-18', '2019-10-22', '2019-10-23',
#                '2019-10-24', '2019-10-25',
#                ...
#                '2021-03-09', '2021-03-10', '2021-03-12', '2021-03-15',
#                '2021-03-16', '2021-03-17', '2021-03-18', '2021-03-19',
#                '2021-03-22', '2021-03-23'],
#               dtype='datetime64[ns]', name='date1', length=359, freq=None)

# %%
df_info
# Out:
#            ADANIPORTS ASIANPAINT AXISBANK BAJAJ-AUTO BAJFINANCE BAJAJFINSV  \
# date1
# 2019-10-11      405.8    1772.25    672.1     2779.5     3959.9    8142.55
# 2019-10-14      402.6    1780.75    684.0     2830.0     3858.0     8065.0
# 2019-10-15     410.35    1788.75    689.9     2890.6     3874.3     8045.0
# 2019-10-16      405.8    1752.15   692.65     2902.0     4015.0     8146.0
# 2019-10-17     404.75    1795.65   710.35     3018.0     4086.0    8311.65
# ...               ...        ...      ...        ...        ...        ...
# 2021-03-17      686.0     2426.0   724.75    3558.15     5357.5     9491.0
# 2021-03-18      680.9     2410.0   718.35    3674.55     5393.4     9445.0
# 2021-03-19      688.0     2411.0    725.2     3645.8     5446.5     9420.9
# 2021-03-22     721.95    2427.95    717.0     3661.5     5384.1     9402.0
# 2021-03-23     736.75     2410.0   730.95     3667.0     5376.0     9425.0
#
# ...

# %%
df_info1.index = pd.to_datetime(df_info.index)

# %%
type(df_info1)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df_info2=df_info

# %%
df_info2.index=df_info1.index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-368-e9f5ec8304cc> in <module>
# ----> 1 df_info2.index=df_info1.index
#
# AttributeError: 'DatetimeIndex' object has no attribute 'index'

# %%
df_info2
# Out:
#            ADANIPORTS ASIANPAINT AXISBANK BAJAJ-AUTO BAJFINANCE BAJAJFINSV  \
# date1
# 2019-10-11      405.8    1772.25    672.1     2779.5     3959.9    8142.55
# 2019-10-14      402.6    1780.75    684.0     2830.0     3858.0     8065.0
# 2019-10-15     410.35    1788.75    689.9     2890.6     3874.3     8045.0
# 2019-10-16      405.8    1752.15   692.65     2902.0     4015.0     8146.0
# 2019-10-17     404.75    1795.65   710.35     3018.0     4086.0    8311.65
# ...               ...        ...      ...        ...        ...        ...
# 2021-03-17      686.0     2426.0   724.75    3558.15     5357.5     9491.0
# 2021-03-18      680.9     2410.0   718.35    3674.55     5393.4     9445.0
# 2021-03-19      688.0     2411.0    725.2     3645.8     5446.5     9420.9
# 2021-03-22     721.95    2427.95    717.0     3661.5     5384.1     9402.0
# 2021-03-23     736.75     2410.0   730.95     3667.0     5376.0     9425.0
#
# ...

# %%
for column in df_info2:
    #print(df_info2[column])
    #if df_info2[column]!= date1:
    df_info2[column] = df_info2[column].str.replace('[\$\,]', '').astype(float)

# %%
df_info2
# Out:
#             ADANIPORTS  ASIANPAINT  AXISBANK  BAJAJ-AUTO  BAJFINANCE  \
# date1
# 2019-10-11      405.80     1772.25    672.10     2779.50      3959.9
# 2019-10-14      402.60     1780.75    684.00     2830.00      3858.0
# 2019-10-15      410.35     1788.75    689.90     2890.60      3874.3
# 2019-10-16      405.80     1752.15    692.65     2902.00      4015.0
# 2019-10-17      404.75     1795.65    710.35     3018.00      4086.0
# ...                ...         ...       ...         ...         ...
# 2021-03-17      686.00     2426.00    724.75     3558.15      5357.5
# 2021-03-18      680.90     2410.00    718.35     3674.55      5393.4
# 2021-03-19      688.00     2411.00    725.20     3645.80      5446.5
# 2021-03-22      721.95     2427.95    717.00     3661.50      5384.1
# 2021-03-23      736.75     2410.00    730.95     3667.00      5376.0
#
#             BAJAJFINSV  BHARTIARTL    BPCL   CIPLA  COALINDIA  ...  \
# ...

# %%
df_daily_returns = df_info2.pct_change()

# %%
df_daily_returns
# Out:
#             ADANIPORTS  ASIANPAINT  AXISBANK  BAJAJ-AUTO  BAJFINANCE  \
# date1
# 2019-10-11         NaN         NaN       NaN         NaN         NaN
# 2019-10-14   -0.007886    0.004796  0.017706    0.018169   -0.025733
# 2019-10-15    0.019250    0.004492  0.008626    0.021413    0.004225
# 2019-10-16   -0.011088   -0.020461  0.003986    0.003944    0.036316
# 2019-10-17   -0.002587    0.024827  0.025554    0.039972    0.017684
# ...                ...         ...       ...         ...         ...
# 2021-03-17   -0.041230   -0.016121 -0.017355   -0.025632   -0.017513
# 2021-03-18   -0.007434   -0.006595 -0.008831    0.032714    0.006701
# 2021-03-19    0.010427    0.000415  0.009536   -0.007824    0.009845
# 2021-03-22    0.049346    0.007030 -0.011307    0.004306   -0.011457
# 2021-03-23    0.020500   -0.007393  0.019456    0.001502   -0.001504
#
#             BAJAJFINSV  BHARTIARTL      BPCL     CIPLA  COALINDIA  ...  \
# ...

# %%
for col in df_info2.columns:
    print(df_info2[col]+ 10)
    #df_daily_returns[col] = df_info2[col].str.replace('[\$\,]', '').astype(float).pct_change()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
# ...

# %%
df_daily_returns = df_daily_returns['ASIANPAINT'].pct_change()

# %%
df_daily_returns['AXISBANK']
# Out:
# date1
# 2019-10-11         NaN
# 2019-10-14    0.017706
# 2019-10-15    0.008626
# 2019-10-16    0.003986
# 2019-10-17    0.025554
#                 ...
# 2021-03-17   -0.017355
# 2021-03-18   -0.008831
# 2021-03-19    0.009536
# 2021-03-22   -0.011307
# 2021-03-23    0.019456
# Name: AXISBANK, Length: 359, dtype: float64

# %%
monthly_returns = df_info2.resample('M').ffill().pct_change()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
# ...

# %%
df_monthly
# Out:
#            ADANIPORTS ASIANPAINT AXISBANK BAJAJ-AUTO BAJFINANCE BAJAJFINSV  \
# date1
# 2019-10-31      392.7     1797.0    732.1     3123.0     4019.0     8125.0
# 2019-11-30      377.8     1694.0    738.6    3058.85     4058.0     9113.9
# 2019-12-31      363.0     1778.2    752.5     3060.0     4215.0     9415.0
# 2020-01-31     366.35     1785.0    731.0     3062.0     4370.1     9460.0
# 2020-02-29     341.65     1798.0    701.0     2768.0     4490.0     9095.0
# 2020-03-31     250.45    1651.15    378.5     2010.0     2214.3     4600.0
# 2020-04-30     290.65    1757.15   444.05     2623.8     2318.0     5090.0
# 2020-05-31      327.0    1670.15    381.9     2708.0    1940.95    4392.55
# 2020-06-30      346.1    1682.15    407.3     2834.0     2828.0     5833.3
# 2020-07-31     315.15    1716.65    432.9     3000.0     3258.0     6213.0
# 2020-08-31     353.55     1891.6   492.85     2959.2     3478.5     6210.0
# ...

# %%
df_info
# Out:
#            ADANIPORTS ASIANPAINT AXISBANK BAJAJ-AUTO BAJFINANCE BAJAJFINSV  \
# date1
# 2019-10-11      405.8    1772.25    672.1     2779.5     3959.9    8142.55
# 2019-10-14      402.6    1780.75    684.0     2830.0     3858.0     8065.0
# 2019-10-15     410.35    1788.75    689.9     2890.6     3874.3     8045.0
# 2019-10-16      405.8    1752.15   692.65     2902.0     4015.0     8146.0
# 2019-10-17     404.75    1795.65   710.35     3018.0     4086.0    8311.65
# ...               ...        ...      ...        ...        ...        ...
# 2021-03-17      686.0     2426.0   724.75    3558.15     5357.5     9491.0
# 2021-03-18      680.9     2410.0   718.35    3674.55     5393.4     9445.0
# 2021-03-19      688.0     2411.0    725.2     3645.8     5446.5     9420.9
# 2021-03-22     721.95    2427.95    717.0     3661.5     5384.1     9402.0
# 2021-03-23     736.75     2410.0   730.95     3667.0     5376.0     9425.0
#
# ...

# %%
df_info2 = pd.DataFrame( dtype=float)

# %%
s

# %%
df_info2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
r = df_info2.pct_change()

# %%
r
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#clculate monthly return by cumulating daily return
mthly_return=df_info2.pct_change().resample('M').agg(lambda x:(x+1).prod()-1)
mthly_return
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
# ...

# %%
# These are all the keys you want
key_names= nifty_50 

# Holds the data you want to pass to the dataframe.
df_info = pd.DataFrame()
df_temp= pd.DataFrame()

#for group_name in Groups:
headers = {
      'Accept': 'application/json',
      'x-session-token':            'a3f2c8842dfbf9375060d013fbd2271f'
    }
# For each group in the groups, we iterate over all the keys we want.

RS_Rating=80
exportList= pd.DataFrame(columns=['Stock', "RS_Rating", "50 Day MA", "150 Day Ma", "200 Day MA", "52 Week Low", "52 week High"])
for key in key_names:
#    headers = {
#      'Accept': 'application/json',
#     'x-session-token':            'a3f2c8842dfbf9375060d013fbd2271f'
#    }

    # Generate a keyname that you want for your dataframe.
    avg_key_name = key 
    print(avg_key_name)
    #std_key_name = key + '_Standard_Dev'
    smaUsed=[50,150,200]
    
    
    
    if avg_key_name not in df_info:
        df_info[avg_key_name] = 0
        #df_info[std_key_name] = []
        
    name = requests.get('https://api.stocknote.com/history/candleData', params={
      f'symbolName': {avg_key_name},  'fromDate': '2019-10-11'
    }, headers = headers)
    
    r=name.json()
    #print(r)
    
    date1=[]
    ltp=[]
    open1=[]
    low1=[]
    high=[]
    volume=[]
    
    for i in range(len(r['historicalCandleData'])):
        date1.append(r['historicalCandleData'][i]['date'])
        ltp.append(r['historicalCandleData'][i]['ltp'])
        open1.append(r['historicalCandleData'][i]['open'])
        low1.append(r['historicalCandleData'][i]['low'])
        high.append(r['historicalCandleData'][i]['high'])
        volume.append(r['historicalCandleData'][i]['volume'])
    df_info[avg_key_name]=ltp
    date1=date1
    df_temp['date']=date1
    df_temp['ltp']= ltp
    df_temp['open']=open1
    df_temp['low']=low1
    df_temp['high']=high
    df_temp['volume']=volume
    #smaUsed=[50,150,200]
    for x in smaUsed:
        sma=x
        df_temp["SMA_"+str(sma)]=round(df_temp.iloc[:,4].rolling(window=sma).mean(),2)
    
    #print((df_temp))
    currentClose=df_temp["ltp"][len(df_temp)-1]
    moving_average_50=df_temp["SMA_50"][len(df_temp)-1]
    moving_average_150=df_temp["SMA_150"][len(df_temp)-1]
    moving_average_200=df_temp["SMA_200"][len(df_temp)-1]
    low_of_52week=min(df_temp["ltp"][-260:])
    high_of_52week=max(df_temp["ltp"][-260:])
    currentClose =       float(currentClose)
    moving_average_50 =  float(moving_average_50)
    moving_average_150 = float(moving_average_150)
    moving_average_200 = float(moving_average_200)
    low_of_52week =  float(low_of_52week)
    high_of_52week =  float(high_of_52week)
        
    
    
    
    try:
        moving_average_200_20 = df_temp["SMA_200"][-20]

    except Exception:
        moving_average_200_20=0
        
        #Condition 1: Current Price > 150 SMA and > 200 SMA
    if(currentClose>moving_average_150>moving_average_200):
        cond_1=True
    else:
        cond_1=False
        #Condition 2: 150 SMA and > 200 SMA
    if(moving_average_150>moving_average_200):
        cond_2=True
    else:
        cond_2=False
        #Condition 3: 200 SMA trending up for at least 1 month (ideally 4-5 months)
    if(moving_average_200>moving_average_200_20):
        cond_3=True
    else:
        cond_3=False
        #Condition 4: 50 SMA> 150 SMA and 50 SMA> 200 SMA
    if(moving_average_50>moving_average_150>moving_average_200):
        #print("Condition 4 met")
        cond_4=True
    else:
        #print("Condition 4 not met")
        cond_4=False
        #Condition 5: Current Price > 50 SMA
    if(currentClose>moving_average_50):
        cond_5=True
    else:
        cond_5=False
    #Condition 6: Current Price is at least 30% above 52 week low (Many of the best are up 100-300% before coming out of consolidation)
    if(currentClose>=(1.3*low_of_52week)):
        cond_6=True
    else:
        cond_6=False
        #Condition 7: Current Price is within 25% of 52 week high
    if(currentClose>=(.75*high_of_52week)):
        cond_7=True
    else:
        cond_7=False
    #Condition 8: IBD RS rating >70 and the higher the better
    if(RS_Rating>70):
        cond_8=True
    else:
        cond_8=False
        
    if(cond_1 and cond_2 and cond_3 and cond_4 and cond_5 and cond_6 and cond_7 and cond_8):
        exportList = exportList.append({'Stock': avg_key_name, "RS_Rating": RS_Rating, "50 Day MA": moving_average_50, "150 Day Ma": moving_average_150, "200 Day MA": moving_average_200, "52 Week Low": low_of_52week, "52 week High": high_of_52week}, ignore_index=True)
    #except Exception:
        #print("No data on "+stock)



    
    
    #print(ltp)
    #df_info[std_key_name].append()
    #print(ltp)
#df_info= df_info.append(date1,axis=1)
#df_info = pd.DataFrame(df_info, index=date1)
#df_dates = df.index
df_info['date1'] = date1
#df_info['date1'] = pd.to_datetime(df['date'])
#df_info = df_info.set_index('date1')
# Out:
# ADANIPORTS
# ASIANPAINT
# AXISBANK
# BAJAJ-AUTO
# BAJFINANCE
# BAJAJFINSV
# BHARTIARTL
# BPCL
# CIPLA
# COALINDIA
# DRREDDY
# EICHERMOT
# GAIL
# GRASIM
# HCLTECH
# HDFC
# HDFCBANK
# HEROMOTOCO
# HINDALCO
# HINDUNILVR
# BRITANNIA
# ICICIBANK
# INDUSINDBK
# INFY
# IOC
# ITC
# JSWSTEEL
# KOTAKBANK
# LT
# M&M
# MARUTI
# NESTLEIND
# NTPC
# ONGC
# POWERGRID
# RELIANCE
# SBIN
# SUNPHARMA
# TCS
# TATAMOTORS
# TATASTEEL
# TECHM
# TITAN
# ULTRACEMCO
# UPL
# VEDL
# WIPRO
# SHREECEM
# ZEEL

# %%
exportList
# Out:
#          Stock RS_Rating  50 Day MA  150 Day Ma  200 Day MA  52 Week Low  \
# 0   ADANIPORTS        80     650.04      484.54      448.42       215.00
# 1   ASIANPAINT        80    2497.07     2344.58     2195.48      1495.10
# 2       GRASIM        80    1253.64      967.87      881.76      1000.65
# 3     HINDALCO        80     304.37      240.64      221.97       100.15
# 4         INFY        80    1333.05     1184.65     1101.52      1001.85
# 5     JSWSTEEL        80     414.95      359.08      323.97       140.35
# 6    TATASTEEL        80     713.41      570.44      517.26       244.35
# 7        TITAN        80    1502.75     1377.47     1293.05      1002.75
# 8   ULTRACEMCO        80    6349.36     5220.33     4908.28      3017.00
# 9         VEDL        80     200.29      150.99      139.84       100.00
# 10    SHREECEM        80   27087.83    24074.47    23643.81     15500.00
#
#     52 week High
# 0         751.55
# 1        2846.00
# 2         994.85
# 3          99.50
# ...
