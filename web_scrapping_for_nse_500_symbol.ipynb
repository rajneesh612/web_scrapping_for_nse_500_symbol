# %%
from lxml import html
import requests

import lxml.html as lh
import pandas as pd
from bs4 import BeautifulSoup

# %%
url='https://www.traderscockpit.com/?pageView=nse-indices-stock-watch&index=NIFTY+500'

# %%
#Create a handle, page, to handle the contents of the website
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
soup= BeautifulSoup(page.text,'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="GumptionLabs Pvt Ltd." name="publisher"/>
# <meta content="GumptionLabs Pvt Ltd." name="copyright"/>
# <meta content="global" name="distribution"/>
# <meta content="Get NSE NIFTY 500 Live Stock/Share prices. Get real-time NIFTY 500 updates on technical indicators and charts. This page contains real-time streaming quotes of the NSE NIFTY 500 Index Components or list of NIFTY 500 stocks/symbols." name="description"/>
# <meta content="NIFTY 500 Stock Watch,NIFTY 500 Stock Prices,NIFTY 500 Index, List of NIFTY 500 stocks,NIFTY 500 Sector Watch" name="keywords"/>
# <title>NIFTY 500 Stock Watch,NIFTY 500 Stock Prices,NIFTY 500 Index, List of NIFTY 500 stocks,NIFTY 500 Sector Watch</title>
# <meta content="Ln71M4L1urUYlyS9-f8DDA7hWtVhtqxHl7bu7JtMg1k" name="google-site-verification"/>
# <meta content="4b36750590132df1" name="y_key"/>
# <meta content="index, follow" name="robots"/>
# <meta content="Free Trading Strategies" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="http://www.TradersCockpit.com" property="og:url"/>
# <meta content="http://www.TradersCockpit.com/images/tc_fb_logo_new.jpg" property="og:image"/>
# <meta content="225112114166630" property="fb:page_id"/>
# <meta content="228402410505812" property="fb:app_id"/><!--App id of www.TradersCockpit.com app -->
# <meta content="693647620,100002378783384" property="fb:admins"/>
# <link href="/manifest.json" rel="manifest"/>
# <link href="/v2/img/favicon4.png" rel="icon" type="image/png"/>
# <link href="/v2/fonts/fonts.css" rel="stylesheet" type="text/css"/>
# <link href="/v2/jquery/jquery-ui.min.css" rel="stylesheet" type="text/css"/>
# <link href="/v2/bootstrap/bootstrap.min.css" rel="stylesheet" type="text/css"/>
# <link href="/v2/css/style.css?v=0.22" rel="stylesheet" type="text/css"/>
# <script src="/v2/jquery/jquery-2.1.0.min.js" type="text/javascript"></script>
# <script src="/v2/jquery/jquery-ui.min.js" type="text/javascript"></script>
# <script src="/v2/js/jquery.touchSwipe.min.js" type="text/javascript"></script>
# <script src="/v2/bootstrap/bootstrap.min.js" type="text/javascript"></script>
# <script src="/v2/js/smooth-scroll.js" type="text/javascript"></script>
# <script src="/v2/js/script.js?v=1.0" type="text/javascript"></script>
# <link href="/css/tc.css?v=2.6" rel="stylesheet" type="text/css"/>
# <script src="/js/fancybox/jquery.fancybox.js?v=2.1.5"></script>
# <script src="/js/jquery-ui-time-picker.js" type="text/javascript"></script>
# <script src="/js/ajax.js?v=0.5" type="text/javascript"></script>
# <script src="/js/boxover.js" type="text/javascript"></script>
# <script src="/js/sourabh-js/bootstrap.min.js" type="text/javascript"></script>
# <link href="/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
# <link href="/js/fancybox/jquery.fancybox.css?v=2.1.5" media="screen" rel="stylesheet" type="text/css"/>
# <link href="/js/dojo-release-1.3.1/dijit/themes/dijit.css" rel="stylesheet"/>
# <link href="/js/dojo-release-1.3.1/dijit/themes/tundra/tundra.css" rel="stylesheet" type="text/css"/>
# <script djconfig="parseOnLoad: true" src="/js/dojo-release-1.3.1/dojo/dojo.js" type="text/javascript"></script>
# <script type="text/javascript">
#
#         var gDarr = ["20 Microns Limited~20MICRONS","21st Century Management Services Limited~21STCENMGM","3i Infotech Limited~3IINFOTECH","3M India Limited~3MINDIA","3P Land Holdings Limited~3PLAND","5Paisa Capital Limited~5PAISA","63 moons technologies limited~63MOONS","8K Miles Software Services Limited~8KMILES","A2Z INFRA ENGINEERING LIMITED~A2ZINFRA","A2Z Maintenance & Engineering Services Limite~A2ZMES","Aakash Exploration Services Limited~AAKASH","Aanjaneya Lifecare Limited~AANJANEYA","Aaron Industries Limited~AARON","Aarti Drugs Limited~AARTIDRUGS","Aarti Industries Limited~AARTIIND","Aarti Surfactants Limited~AARTISURF","Aarvee Denims & Exports Limited~AARVEEDEN","Aarvi Encon Limited~AARVI","Aavas Financiers Limited~AAVAS","Aban Offshore Limited~ABAN","ABB Limited~ABB","Abbott India Limited~ABBOTINDIA","Aditya Birla Capital Limited~ABCAPITAL","Aditya Birla Chemicals (India) Limited~ABCIL","Aditya Birla Fashion and Retail Limited~ABFRL","ABG Shipyard Limited~ABGSHIP","Abhishek Corporation Limited~ABHISHEK","Aditya Birla Nuvo Limited~ABIRLANUVO","ABM International Limited~ABMINTLTD","ACC Limited~ACC","Accelya Kale Solutions Limited~ACCELYA","Accuracy Shipping Limited~ACCURACY","Action Construction Equipment Limited~ACE","Acropetal Technologies Limited~ACROPETAL","Acrysil Limited~ACRYSIL","Adani Enterprises Limited~ADANIENT","Adani Gas Limited~ADANIGAS","Adani Green Energy Limited~ADANIGREEN","Adani Ports and Special Economic Zone Limited~ADANIPORTS","Adani Power Limited~ADANIPOWER","Adani Transmission Limited~ADANITRANS","ADF Foods Limited~ADFFOODS","Adhunik Metaliks Limited~ADHUNIK","Adhunik Industries Limited~ADHUNIKIND","Adi Finechem Limited~ADI","Archidply Decor Limited~ADL","Adlabs Entertainment Limited~ADLABS","Ador Welding Limited~ADORWELD","Adroit Infotech Limited~ADROITINFO","Allied Digital Services Limited~ADSL","Advani Hotels & Resorts (India) Limited~ADVANIHOTR","Advanta India Limited~ADVANTA","Advanced Enzyme Technologies Limited~ADVENZYMES","Aegis Logistics Limited~AEGISCHEM","Affle (India) Limited~AFFLE","Accel Frontline Limited~AFL","Aftek Limited~AFTEK","Agarwal Industrial Corporation Limited~AGARIND","AGC Networks Limited~AGCNET","Artemis Global Life Sciences Limited~AGLSL","Agri Tech (India) Limited~AGRITECH","Agro Dutch Industries Limited~AGRODUTCH","Agro Phos India Limited~AGROPHOS","Ahlada Engineers Limited~AHLADA","Asian Hotels (East) Limited~AHLEAST","Ahluwalia Contracts (India) Limited~AHLUCONT","Asian Hotels (West) Limited~AHLWEST","AIA Engineering Limited~AIAENG","AI Champdany Industries Limited~AICHAMP","Ashapura Intimates Fashion Limited~AIFL","Alstom India Limited~AIL","Monnet Ispat & Energy Limited~AIONJSW","Airan Limited~AIRAN","Ajanta Pharma Limited~AJANTPHARM","Ajmera Realty & Infra India Limited~AJMERA","Akash Infra Projects Limited~AKASH","Akg Exim Limited~AKG","AksharChem India Limited~AKSHARCHEM","Aksh Optifibre Limited~AKSHOPTFBR","Akzo Nobel India Limited~AKZOINDIA","Alankit Limited~ALANKIT","Albert David Limited~ALBERTDAVD","Allahabad Bank~ALBK","Alchemist Limited~ALCHEM","Alembic Limited~ALEMBICLTD","Alicon Castalloy Limited~ALICON","Alkali Metals Limited~ALKALI","Alkem Laboratories Limited~ALKEM","Alkyl Amines Chemicals Limited~ALKYLAMINE","Allcargo Global Logistics Limited~ALLCARGO","Allsec Technologies Limited~ALLSEC","Almondz Global Securities Limited~ALMONDZ","Alok Industries Limited~ALOKINDS","Alok Industries Limited~ALOKTEXT","Alpa Laboratories Limited~ALPA","Alphageo (India) Limited~ALPHAGEO","Alpine Housing Development Corporation Limite~ALPINEHOU","Alps Industries Limited~ALPSINDUS","Alstom T&D India Limited~ALSTOMT&D","Amar Remedies Limited~AMAR","Amara Raja Batteries Limited~AMARAJABAT","Amarjothi Spinning Mills Limited~AMARJOTHI","Amber Enterprises India Limited~AMBER","Ambika Cotton Mills Limited~AMBIKCO","Ambuja Cements Limited~AMBUJACEM","AMD Industries Limited~AMDIND","Amj Land Holdings Limited~AMJLAND","AML Steel Limited~AMLSTEEL","Amrutanjan Health Care Limite ...
#
#     </script>
# </head>
# <body>
# <div class="disable">
# </div>
# <script type="text/javascript">
#     function nonMobileSignIn() {
#         $('#gl_loginButton').attr('disabled','true');
#         if ($("#gl_loginName1").val().length < 1 || $("#gl_password1").val().length < 1) {
#
#             $("#login_error").html('Please, enter both Email Id and Password.');
#             $("#login_error").show();
#             $('#gl_loginButton').removeAttr('disabled');
#             return false;
#         }
#
#         $.ajax({
#             type        : "POST",
#             cache   : false,
#             url     : "/LoginController?url=true&referrer=https%3A%2F%2Fwww.traderscockpit.com%2F%3FpageView%3Dnse-indices-stock-watch%26index%3DNIFTY%2B500"+"&"+$('#login_form').serialize(),
# //            data        : $('#login_form').serializeArray(),
# //                data        : 'js=1',
#             success: function(data) {
#                 var msg = data.LOGIN_MESSAGE;
#                 if(msg === 'SUCCESS') {
#                     var location = window.location.toString();
#                     if(location.indexOf("#") > 0) {
#                         location = location.replace("#","");
#                     }
#
#                     window.location = location;
#                 } else {
#                     $("#login_error").html(msg);
#                     $("#login_error").show();
#                     $('#gl_loginButton').removeAttr('disabled');
#                 }
#             }
#         });
#         return false;
#     }
#
#     function mobileSignIn() {
#         $('#m_gl_loginButton').attr('disabled','true');
#         if ($("#m_gl_loginName1").val().length < 1 || $("#m_gl_password1").val().length < 1) {
#
#             $("#m_login_error").html('Please, enter both Email Id and Password.');
#             $("#m_login_error").show();
#             $('#m_gl_loginButton').removeAttr('disabled');
#             return false;
#         }
#
#         $.ajax({
#             type        : "POST",
#             cache   : false,
#             url     : "/LoginController?url=true&referrer=https%3A%2F%2Fwww.traderscockpit.com%2F%3FpageView%3Dnse-indices-stock-watch%26index%3DNIFTY%2B500"+"&"+$('#m_login_form').serialize(),
#             success: function(data) {
#                 var msg = data.LOGIN_MESSAGE;
#                 if(msg === 'SUCCESS') {
#                     var location = window.location.toString();
#                     if(location.indexOf("#") > 0) {
#                         location = location.replace("#","");
#                     }
#
#                     window.location = location;
#                 } else {
#                     $("#m_login_error").html(msg);
#                     $("#m_login_error").show();
#                     $('#m_gl_loginButton').removeAttr('disabled');
#                 }
#             }
#         });
#         return false;
#     }
#
#     var odd=false;
#     $(document).ready(function(){
#         $("#search-box").autocomplete({
#             source:gDarr,
#             select:function(evt, ui){
#                 var tar=ui.item.label.split("~");
#                 $(evt.target).val(tar[0]);
#                 /*$("#symbolFilter").val($.trim(tar[1]));
#                 $("#companyNameFilter").val($.trim(tar[0]));
#                 $("#searchAnalysisType").val($('#tempSearchOption').val());
#                 console.log("Search "+$('#search-type-select').val());*/
#                 if($('#search-type-select').val() === 'quote and analysis') {
#                     $("#headerSearchForm").attr('action','?pageView=symbol-analysis&company='+encodeURIComponent($.trim(tar[0]))+'&symbol='+encodeURIComponent($.trim(tar[1])));
#                     $("#headerSearchForm").submit();
#                 } else {
#                     $("#headerSearchForm").attr('action','?pageView=futures-and-options-chain-analysis&fo_symbol='+encodeURIComponent($.trim(tar[1]))+'&company='+encodeURIComponent($.trim(tar[0])) );
#                     $("#headerSearchForm").submit();
#                 }
#
#             }
#         }).autocomplete("instance")._renderItem=function(ul, item){
#             $(ul).addClass("sa-container");
#             if(odd) {
#                 li=$("<li/>").addClass("stock-autocomplete").data("item.autocomplete",item).append(item.label).appendTo(ul);
#                 odd=false;
#             }else{
#                 li=$("<li/>").addClass("sa-odd").addClass("stock-autocomplete").data("item.autocomplete",item).append(item.label).appendTo(ul);
#                 odd=true;
#             }
#             return li;
#         };
#     });
#
#     var mobileOdd=false;
#     $(document).ready(function(){
#         $("#m-search-box").autocomplete({
#             source:gDarr,
#             select:function(evt, ui){
#                 var tar=ui.item.label.split("~");
#                 $(evt.target).val(tar[0]);
#                 /*$("#symbolFilter").val($.trim(tar[1]));
#                 $("#companyNameFilter").val($.trim(tar[0]));
#                 $("#searchAnalysisType").val($('#tempSearchOption').val());
#                 console.log("Search "+$('#search-type-select').val());*/
#                 if($('#m-search-type-select').val() === 'quote and analysis') {
#                     $("#m-headerSearchForm").attr('action','?pageView=symbol-analysis&company='+encodeURIComponent($.trim(tar[0]))+'&symbol='+encodeURIComponent($.trim(tar[1])));
#                     $("#m-headerSearchForm").submit();
#                 } else {
#                     $("#m-headerSearchForm").attr('action','?pageView=futures-and-options-chain-analysis&fo_symbol='+encodeURIComponent($.trim(tar[1]))+'&company='+encodeURIComponent($.trim(tar[0])) );
#                     $("#m-headerSearchForm").submit();
#                 }
#
#             }
#         }).autocomplete("instance")._renderItem=function(ul, item){
#             $(ul).addClass("sa-container");
#             if(mobileOdd) {
#                 li=$("<li/>").addClass("stock-autocomplete").data("item.autocomplete",item).append(item.label).appendTo(ul);
#                 mobileOdd=false;
#             }else{
#                 li=$("<li/>").addClass("sa-odd").addClass("stock-autocomplete").data("item.autocomplete",item).append(item.label).appendTo(ul);
#                 mobileOdd=true;
#             }
#             return li;
#         };
#     });
# </script>
# <div class="container-fluid" id="top-container">
# <!--
#         Header comes here
#     -->
# <nav class="navbar navbar-default hidden-md hidden-sm hidden-lg" role="navigation">
# <!-- Brand and toggle get grouped for better mobile display -->
# <div class="navbar-header">
# <button class="navbar-toggle" data-target="#navbarCollapse" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <a class="navbar-brand" href="?pageView=home"><img alt="TradersCockpit" src="/v2/img/logo.png"/></a>
# <div class="dd-mobile-menu-open">
# <a href="#"><i class="fa fa-ellipsis-vertical"></i></a>
# <div class="dd-mobile-menu">
# <a class="sign-in-open navbar-toggle" data-target="#signinbarCollapse" data-toggle="collapse" href="#"><i class="fa fa-user"></i> Sign In / Register</a>
# <a class="search-open navbar-toggle" data-target="#searchbarCollapse" data-toggle="collapse" href="#"><i class="fa fa-search"></i> Search Symbol</a>
# </div>
# </div>
# </div>
# <!-- Collection of nav links, forms, and other content for toggling -->
# <div class="collapse navbar-collapse" id="navbarCollapse">
# <ul class="nav navbar-nav">
# <!--  /////////////////////////////////////////////////////////////////////////////////////////// -->
# <li class="dropdown">
# <a class="active dropdown-toggle" data-toggle="dropdown" href="#">MyCockpit <b class="caret"></b></a>
# <ul class="dropdown-menu" role="menu">
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">My Cockpit <b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="?pageView=updateProfile">My Profile</a></li>
# <li><a href="?pageView=my-watchlist">My WatchList</a></li>
# <li><a href="?pageView=my-stock-screener">My Stock Screeners</a></li>
# <li><a href="?pageView=my-sms-history">My SMS History</a></li>
# <li><a href="?pageView=my-strategies&amp;type=myStrategies">My Strategies</a></li>
# <li><a href="?pageView=subscribe-to-notifications">Subscribe to Notifications</a></li>
# <li><a href="?pageView=auto-profiling">Take Survey</a></li>
# <li id="demat-menu"><a href="https://accounts.compositedge.com/dcob/#/login?source=B&amp;id=58-TC1" target="_blank">Open Demat Account Free</a></li>
# </ul>
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">My Screening Dashboard<b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="?pageView=intraday-dashboard">TC Intraday Dashboard</a></li>
# <li><a href="?pageView=custom-rt-screener-dashboard">TC 3.15pm Screening Dashboard</a></li>
# <li><a href="?pageView=custom-screener-dashboard">TC EOD Screening Dashboard</a></li>
# <li><a href="?pageView=custom-weekly-screener-dashboard">Weekly Screening Dashboard</a></li>
# <li><a href="?pageView=custom-investment-dashboard">TC Investment Dashboard</a></li>
# <li><a href="?pageView=custom-options-screener-dashboard">Monthly Options Dashboard</a></li>
# <li><a href="?pageView=weekly-options-screener-dashboard">Weekly Options Dashboard</a></li>
# </ul>
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Misc<b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="http://traderscockpit.uservoice.com/" target="_blank">Create Support System</a></li>
# <li><a href="http://traderscockpit.uservoice.com/knowledgebase" target="_blank">FAQ / Knowledgebase</a></li>
# <li><a href="?pageView=technical-analysis-training-videos">FAQ Videos</a></li>
# <!--    <li><a href="?pageView=give-testimonial">Give Testimonial</a></li>-->
# <li><a href="?pageView=mobile-verification">Mobile Verification</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <!--  /////////////////////////////////////  market //////////////////////////////////// -->
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Markets <b class="caret"></b></a>
# <ul class="dropdown-menu" role="menu">
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown">Markets<b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="?pageView=india-stock-market-analysis">Nse Today</a></li>
# <li><a href="?pageView=nse-top-gainers">Top Gainers</a></li>
# <li><a href="?pageView=nse-top-losers">Top Losers</a></li>
# <li><a href="?pageView=nse-dynamic-heatmap">Dynamic HeatMap</a></li>
# <li><a href="?pageView=live-nse-indices-watch">Live Indices Watch</a></li>
# <!--     NF  --> <li><a href="#">Volume Buzzers</a></li>
# <li><a href="?pageView=nse-concurrent-gainers">Concurrent Gainers / Losers</a></li>
# </ul>
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">FO Analysis<b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="?pageView=long-positions-fresh-longs">Fresh Longs</a></li>
# <li><a href="?pageView=short-sell-fresh-shorts">Fresh Shorts</a></li>
# <li><a href="?pageView=short-covering">Short Covering</a></li>
# <li><a href="?pageView=long-unwinding">Long Unwinding</a></li>
# <li><a href="?pageView=symbol-analysis&amp;company=NIFTY&amp;symbol=NIFTY&amp;stock-analysis=NIFTY-end-of-day-stock-analysis&amp;tickType=0">Nifty Analysis</a></li>
# <li><a href="?pageView=nse-futures-spot-arbitrage">Futures Spot Arbitrage</a></li>
# </ul>
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Advances/Declines (AD)<b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="?pageView=live-nse-advance-decline-ratio-chart">Live AD Ratio Chart</a></li>
# <li><a href="?pageView=historical-nse-advance-decline-ratio-chart-and-nse-adline-chart">Historical AD Ratio Chart</a></li>
# </ul>
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">FII / DII<b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="?pageView=fii-dii-activity">FII / DII Chart</a></li>
# <li><a href="?pageView=fii-dii-in-india">FII / DII Activities</a></li>
# </ul>
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Misc <b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="?pageView=52-week-high">52 Week High</a></li>
# <li><a href="?pageView=52-week-low">52 Week Low</a></li>
# <!-- <li><a href="?pageView=latest-quarterly-results">Quarterly Results</a></li>-->
# <li><a href="?pageView=latest-corporate-announcements">Corporate Announcements</a></li>
# <li><a href="?pageView=delivery-percentage">Delivery Percentage</a></li>
# <li><a href="?pageView=historical-delivery-details">Delivery Details</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <!--  /////////////////////////////////////////////////////////////////////////////////// -->
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Ready Made <b class="caret"></b></a>
# <ul class="dropdown-menu" role="menu">
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Ready to Use<b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="?pageView=intraday-dashboard">Stock Intraday Dashboard</a></li>
# <li><a href="?pageView=tc-intraday-strategy-dashboards">Intraday Trading System</a></li>
# <li><a href="?pageView=tc-strategy-dashboards">Short Term Trading System</a></li>
# <li><a href="?pageView=relative-stock-strength&amp;symbol=RELIANCE&amp;score-analysis=RELIANCE-sector-score-analysis">Stock Technical Score</a></li>
# <li><a href="?pageView=popular-technical-stock-screeners">Pre-Created Screeners</a></li>
# </ul>
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Technical Dashboards<b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="?pageView=custom-rt-screener-dashboard">TC 3.15pm Dashboard</a></li>
# <li><a href="?pageView=popular-technical-stock-screeners">TC Multi Screening Dashboard</a></li>
# <li><a href="?pageView=custom-options-screener-dashboard">Monthly Options Dashboard</a></li>
# <li><a href="?pageView=weekly-options-screener-dashboard">Weekly Options Dashboard</a></li>
# <li><a href="?pageView=intraday-wl-dashboard">My WatchGroup Intraday Dashboard</a></li>
# <li><a href="?pageView=iv-dashboard">IV Scanner Dashboard</a></li>
# </ul>
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">SmartCase<b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="?pageView=tc-smartcase-one">Trading Smartcase - 3 PM</a></li>
# <li><a href="?pageView=tc-smartcase-eod">Trading Smartcase EOD</a></li>
# <li><a href="?pageView=tc-smartcase-weekly">Investing SmartCase</a></li>
# </ul>
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">EOD , Weekly Dashboard<b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="?pageView=custom-screener-dashboard">TC EOD Screening Dashboard</a></li>
# <li><a href="?pageView=custom-weekly-screener-dashboard">Weekly Screening Dashboard</a></li>
# <li><a href="?pageView=custom-investment-dashboard">TC Investment Dashboard</a></li>
# <li><a href="?pageView=intraday-historical-dashboard">Historical IntraDay Dashboard</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">ChartX <b class="caret"></b></a>
# <ul class="dropdown-menu" role="menu">
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Live Technical Charts<b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="?pageView=nse-interactive-technical-charts" title="Interactive NSE Technical Charts for Smart Phones">Interactive Technical Charts</a></li>
# <li><a href="?pageView=free-nse-intraday-charts" title="Free NSE IntraDay charts">Free NSE IntraDay Charts</a></li>
# <li><a href="?pageView=new-advanced-charts" title="NSE Advanced Charts with TrendLines and Proprietary Indicators">Advanced (Proprietary Indicators) Charts</a></li>
# <li><a href="?pageView=renko-chart" title="NIFTY Renko Chart and PF Chart">Renko, Heikin Ashi and P&amp;F Chart</a></li>
# <li><a href="?pageView=nse-spread-chart" title="NSE Spread Charts">NSE Spread Chart</a></li>
# <li><a href="?pageView=forex-charts" title="Interactive Forex Charts">Interactive Forex Charts</a></li>
# </ul>
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Misc Charts<b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="?pageView=nse-dynamic-heatmap" title="NSE Dynamic Heatmap">Dynamic HeatMap</a></li>
# <li><a href="?pageView=live-nse-advance-decline-ratio-chart" title="Live NSE Advance Decline Ratio Chart">Live AD Ratio Chart</a></li>
# <li><a href="?pageView=india-volatility-index-chart-vs-nifty-chart" title="IndiaVIX V/S NIFTY Chart">India VIX v/s NIFTY Chart</a></li>
# <li><a href="?pageView=fii-dii-activity" title="FII &amp; DII v/s Nifty Chart">FII &amp; DII Chart</a></li>
# <li><a href="?pageView=nifty-pe-ratio-chart-and-pb-dividend-yield-chart" title="NSE Indices PE Charts and Dividend Yield Chart">PE, PB, Div. Yield Chart</a></li>
# <li><a href="?pageView=nse-minute-candle-chart" title="Stock One Minute Chart">One Minute Chart</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">ToolX <b class="caret"></b></a>
# <ul class="dropdown-menu" role="menu">
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Screeners <b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="?pageView=nse-stock-screener">NSE Stock Screener</a></li>
# <li><a href="?pageView=popular-technical-stock-screeners">Ready to use Screeners</a></li>
# <li><a href="?pageView=realtime-candlestick-patterns">Realtime CandleSticks Screener</a></li>
# <li class="nobullet"><a href="?pageView=technical-screener-home">More &gt;&gt;</a></li>
# </ul>
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Stock Alert <b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="?pageView=add-stock-alert">Create New Alert</a></li>
# <li><a href="?pageView=my-stock-alerts">My Alerts</a></li>
# </ul>
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Patterns Scanner<b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="?pageView=short-term-pattern-screener">Pattern and Trendline Scanner</a></li>
# <li><a href="?pageView=bollinger-band-m-pattern">BBand M &amp; W Scanner</a></li>
# <li><a href="?pageView=intraday-divergence-screener">IntraDay Divergences Scanner</a></li>
# <li><a href="?pageView=short-term-divergence-screener">Short Term Divergences Screener</a></li>
# <li><a href="?pageView=intraday-pattern-screener">IntraDay Pattern Scanner</a></li>
# <li><a href="?pageView=intraday-bollinger-band-m-pattern">W and M Pattern(Intraday)</a></li><li class="nobullet"><a href="#">More &gt;&gt;</a></li>
# </ul>
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Calculators <b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="?pageView=position-size-calculator">Position Size Calculator</a></li>
# <li><a href="?pageView=gann-square-of-9-calculator">Gann Square Calculator</a></li>
# <li><a href="?pageView=fibonacci-calculator-and-fibonacci-retracements">Fibonacci Calculator</a></li>
# <li><a href="?pageView=pivot-point-calculator">Pivot Point Calculator</a></li>
# <li><a href="?pageView=options-black-scholes-calculator">Options Greek Calculator</a></li>
# </ul>
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">EOD Analysis Tools<b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="?pageView=futures-options">Futures &amp; OI</a></li>
# <li><a href="?pageView=nifty-volatility">Stock Volatility</a></li>
# <li><a href="?pageView=delivery-percentage">Delivery Percentage</a></li>
# <li><a href="?pageView=support-resistance-analysis">S&amp;R (Pivot)</a></li>
# <li class="nobullet"><a href="?pageView=end-of-day-nse-technical-analysis-tool">More &gt;&gt;</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <!--OptionsX-->
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">OptionsX <b class="caret"></b></a>
# <ul class="dropdown-menu" role="menu">
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Options Analysis <b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="?pageView=futures-and-options-chain-analysis">Option Chain &amp; Analysis</a></li>
# <li><a href="?pageView=easy-options">Easy Options Strategies</a></li>
# <li><a href="?pageView=custom-options-screener-dashboard">Monthly Options Dashboard</a></li>
# <li><a href="?pageView=weekly-options-screener-dashboard">Weekly Options Dashboard</a></li>
# <li><a href="?pageView=options-pain">Option Pain</a></li>
# <li><a href="?pageView=put-call-ratio-analysis">Put Call Ratio Analysis</a></li>
# <li class="nobullet"><a href="?pageView=options-home-page">More &gt;&gt;</a></li>
# </ul>
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Option Strategy Portfolio Tracker <b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="?pageView=options-spread-maker">Create Option Strategy</a></li>
# <li><a href="?pageView=my-options-strategy">My Options Strategies</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <!--  /////////////////////////////////////  strategy x //////////////////////////////////// -->
# <!--        //////////////////////////////  knowledgeX ///////////////////////////////////////////// -->
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Trainings<b class="caret"></b></a>
# <ul class="dropdown-menu" role="menu">
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Technical Workshops<b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="?pageView=technical-analysis-training"> Technical Analysis WorkShop</a></li>
# <!--<li><a href="?pageView=advanced-ta-training">Algorithmic Trading System Workshop</a></li> -->
# <li><a href="?pageView=options-training">Futures and Options WorkShop</a></li>
# <li><a href="http://tcacademy.in" target="_blank" title="Technical Analysis">Other Courses</a></li>
# <!--   <li><a href="?pageView=day-trading-techniques">Day Trading Techniques</a></li>
#                                  <li><a href="?pageView=special-nifty-day-trading-techniques">Nifty Day Trading Techniques</a></li>-->
# </ul>
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Misc <b class="caret"></b></a>
# <ul class="dropdown-menu level-2" role="menu">
# <li><a href="?pageView=technical-analysis-training-videos" title="FAQ Videos">FAQ (Product) Videos</a></li>
# <li><a href="?pageView=traderscockpit-product-details" title="TradersCockpit Product Details">TradersCockpit Product Details<sup style="font-size: 10px;color: #ff0000;">NEW</sup></a></li>
# <li><a href="?pageView=webinars-on-technical-analysis" rel="nofollow" title="Free Live Webinars">Free Live Webinars</a></li>
# <li><a href="?pageView=technical-analysis-training-videos#webinar" rel="nofollow" title="Free Recorded Webinars">Free Recorded Webinars</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <!--  ///////////////////////////////////////////////////////////////////////////
#                <li class="dropdown">
#                    <a data-toggle="dropdown" class="dropdown-toggle" href="http://www.directmf.in" target="_blank">Direct MutualFunds</a>
#                </li>
# -->
# </ul>
# </div>
# <div class="collapse searchbar-collapse" id="searchbarCollapse">
# <i class="close-mobile-menu fa fa-close pull-right"></i>
# <div class="search-box">
# <form action="#" class="form" id="m-headerSearchForm" method="post" name="m-headerSearchForm">
# <select class="search-type" id="m-search-type-select" name="m-search-type">
# <option value="quote and analysis">Quote &amp; Analysis</option>
# <option value="fo analysis">F &amp; O Analysis</option>
# </select>
# <input class="form-control field ac_input" id="m-search-box" name="m-symbolFilterHelper" onblur='if (this.value == "") { this.value = "Search Symbol"; }' onfocus='if (this.value == "Search Symbol") { this.value = ""; }' type="text" value="Search Symbol"/>
# <input id="m-search-box-submit" type="button"/>
# </form>
# <div style="clear:both;"></div>
# </div>
# </div>
# <div class="collapse signinbar-collapse" id="signinbarCollapse">
# <i class="close-mobile-menu fa fa-close pull-right"></i>
# <div class="search-box">
# <div class="sign-in-container">
# <form action="/LoginController?url=true&amp;referrer=https%3A%2F%2Fwww.traderscockpit.com%2F%3FpageView%3Dnse-indices-stock-watch%26index%3DNIFTY%2B500" id="m_login_form" method="post">
# <table>
# <tr><td><span id="m_login_error"></span></td></tr>
# <tr>
# <td>
# <input class="username" id="m_gl_loginName1" name="gl_loginName" placeholder="Login ID (Email ID)" type="text"/>
# </td>
# </tr>
# <tr><td><input class="password" id="m_gl_password1" name="gl_password" placeholder="Password" type="password"/><input id="m_gl_loginFromPopUp" name="gl_loginFromPopUp" type="hidden" value="true"/></td></tr>
# <tr><td><input id="m_gl_rememberMe" name="gl_rememberMe" type="checkbox"/> Remember Me</td></tr>
# <tr><td><input class="sign-in-submit" id="m_gl_loginButton" name="gl_loginButton" onclick="return mobileSignIn()" type="submit" value="Sign in"/></td></tr>
# <tr><td><a href="?pageView=forgot-password">Forgot Password</a></td></tr>
# <tr><td><a href="?pageView=selfRegistration" title="Register for Free">New User? Sign up here</a></td></tr>
# <tr><td><a href="?pageView=email-verification" title="Re-Send Verification Email">Re-Send Verification Email</a></td></tr>
# </table>
# </form>
# </div>
# </div>
# </div>
# </nav>
# <div class="container hidden-xs" id="header-container">
# <div class="row" id="top-nav">
# <div class="col-sm-4 col-md-4 col-lg-4"> </div>
# <div class="col-sm-5 col-md-5 col-lg-5" id="sibling-tabs">
# <ul id="sibling-tabs-ul">
# <!--  <li class="active"><a href="#">Equity</a></li>
#                    <li><a href="http://commodity.traderscockpit.com" target="_blank" title="MCX Commodity Analysis">Commodity</a></li>
#                     <li><a href='http://commodity.traderscockpit.com/?pageView=realtime-currency-technical-analysis-chart' target="_blank" title='Realtime Currency Technical Analysis Chart'>Currency</a></li>
#                 -->
# </ul>
# <ul id="icon-tabs-ul">
# <li><a href="https://play.google.com/store/apps/details?id=com.traderscockpit&amp;hl=en" target="_blank"><img src="/v2/img/phone_icon.jpg"/></a></li>
# </ul>
# <div style="clear:both;"></div>
# </div>
# <div class="col-sm-3 col-md-3 col-lg-3" id="enter-links" style="position:relative;">
# <ul id="entry-tabs-ul">
# <li class="sign-in-li dd-menu"><a class="sign-in-open" href="#">Sign in</a>
# <div class="sign-in-modal custom-modal">
# <div class="sign-in-container">
# <table>
# <form action="/LoginController?url=true&amp;referrer=https%3A%2F%2Fwww.traderscockpit.com%2F%3FpageView%3Dnse-indices-stock-watch%26index%3DNIFTY%2B500" id="login_form" method="post">
# <tr><td><span id="login_error"></span></td></tr>
# <tr>
# <td>
# <input class="username" id="gl_loginName1" name="gl_loginName" placeholder="Login ID (Email ID)" type="text"/>
# </td>
# </tr>
# <tr><td><input class="password" id="gl_password1" name="gl_password" placeholder="Password" type="password"/><input id="gl_loginFromPopUp" name="gl_loginFromPopUp" type="hidden" value="true"/></td></tr>
# <tr><td><input id="gl_rememberMe" name="gl_rememberMe" type="checkbox"/>
# <label for="gl_rememberMe" style="font: 13px arial;">Remember Me</label></td></tr>
# <tr><td><input class="sign-in-submit" id="gl_loginButton" name="gl_loginButton" onclick="return nonMobileSignIn()" type="submit" value="Sign in"/></td></tr>
# </form>
# <tr><td><a href="?pageView=forgot-password">Forgot Password?</a></td></tr>
# <tr><td><a href="?pageView=selfRegistration" title="Register for Free">New User? Sign up here</a></td></tr>
# <tr><td><a href="?pageView=email-verification" title="Re-Send Verification Email">Re-Send Verification Email</a></td></tr>
# </table>
# </div>
# </div>
# </li>
# <li><a href="?pageView=selfRegistration" title="Register for Free">Register for Free</a></li>
# <li class="call-us-li dd-menu">
# <a href="#">Call Us</a>
# <div class="call-us-modal custom-modal">
# <div><i class="fa fa-phone"></i> 080-61971464</div>
# <div><i class="fa fa-phone"></i> +91-8050502121</div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="row" id="logo-panel">
# <div class="col-sm-4 col-md-4 col-lg-4" id="logo-container">
# <a class="logo-link" href="/">
# <img class="logo" src="/v2/img/logo.png"/>
# </a>
# </div>
# <div class="col-sm-5 col-md-5 col-lg-5" id="search-box-column">
# <div style="border:1px solid #fff">
# <form action="#" class="form" id="headerSearchForm" method="post" name="headerSearchForm">
# <select class="search-type" id="search-type-select" name="search-type">
# <option value="quote and analysis">Quote &amp; Analysis</option>
# <option value="fo analysis">F &amp; O Analysis</option>
# </select>
# <input class="form-control field ac_input" id="search-box" name="symbolFilterHelper" onblur='if (this.value == "") { this.value = "Search Symbol"; }' onfocus='if (this.value == "Search Symbol") { this.value = ""; }' type="text" value="Search Symbol"/>
# <input id="search-box-submit" type="button"/>
# </form>
# <div style="clear:both;"></div>
# </div>
# </div>
# <div class="col-sm-3 col-md-3 col-lg-3"> </div>
# </div>
# </div>
# <div class="container-fluid hidden-xs" id="nav-fluid-container">
# <div class="container">
# <div class="row">
# <div class="col-sm-12 col-lg-12 col-md-12" id="nav-panel">
# <ul>
# <li class="home-nav no-submenu"><a href="?pageView=home"><img src="/v2/img/home_icon.png"/></a></li>
# <li class="no-bullet" id="my-cockpit-menu"><a href="?pageView=my-cockpit">My Cockpit</a></li>
# <li id="markets-menu"><a href="?pageView=markets">Markets</a></li>
# <li id="dashboardx-menu"><a href="?pageView=dashboardx">ReadyMade</a></li>
# <!--<li id="f-menu"><a href="?pageView=chartx">DashboardX</a></li>-->
# <li id="chartx-menu"><a href="?pageView=chartx">ChartX</a></li>
# <li id="toolsx-menu"><a href="?pageView=toolsx">ToolsX</a></li>
# <li id="optionsx-menu"><a href="?pageView=options-home-page">OptionsX</a></li>
# <li id="knowledgex-menu"><a href="?pageView=stock-market-training">Trainings</a></li>
# <li id="wealth-menu"><a href="https://wealth.traderscockpit.com/" target="_blank">Wealth</a></li>
# <!-- <li id='autopilot-menu'><a href="?pageView=autopilot">AutoPilot</a></li>-->
# <li></li>
# </ul>
# <div style="clear:both;"></div>
# <div class="expanded-menu-container">
# <div class="my-cockpit-menu specific-menu">
# <div class="row">
# <div class="col-sm-3 col-md-3 col-lg-3">
# <a class="nav-level-1"><img class="secLevelIcon" src="/v2/img/myTradersCockpit_white.png"/>My Cockpit</a>
# <ul>
# <li><a href="?pageView=updateProfile">My Profile</a></li>
# <li><a href="?pageView=my-watchlist">My WatchList</a></li>
# <li><a href="?pageView=my-stock-screener">My Stock Screeners</a></li>
# <li><a href="?pageView=my-sms-history">My SMS History</a></li>
# <li><a href="?pageView=my-strategies&amp;type=myStrategies">My Strategies</a></li>
# <li><a href="https://www.traderscockpit.com/?pageView=subscribe-to-notifications">Subscribe to Notifications</a></li>
# <li><a href="?pageView=auto-profiling">Take Survey</a></li>
# <li id="demat-menu"><a href="https://accounts.compositedge.com/dcob/#/login?source=B&amp;id=58-TC1" target="_blank">Open Demat Account Free</a></li>
# </ul>
# </div>
# <div class="col-sm-3 col-md-3 col-lg-3">
# <a class="nav-level-1"><img class="secLevelIcon" src="/v2/img/screener_icon_white.png"/>My Screening Dashboard</a>
# <ul>
# <li><a href="?pageView=intraday-dashboard">Stockwise Intraday Dashboard</a></li>
# <li><a href="?pageView=custom-rt-screener-dashboard">TC 3.15pm Dashboard</a></li>
# <li><a href="?pageView=custom-screener-dashboard">TC EOD Screening Dashboard</a></li>
# <li><a href="?pageView=custom-weekly-screener-dashboard">Weekly Screening Dashboard</a></li>
# <li><a href="?pageView=custom-investment-dashboard">TC Investment Dashboard</a></li>
# <li><a href="?pageView=custom-options-screener-dashboard">Monthly Options Dashboard</a></li>
# <li><a href="?pageView=weekly-options-screener-dashboard">Weekly Options Dashboard</a></li>
# <li><a href="?pageView=intraday-historical-dashboard">Historical IntraDay Dashboard</a></li>
# </ul>
# </div>
# <div class="col-sm-3 col-md-3 col-lg-3">
# <a class="nav-level-1"><img class="secLevelIcon" src="/v2/img/misc_white.png"/>Misc</a>
# <ul>
# <li><a href="http://traderscockpit.uservoice.com/" target="_blank">Create Support Ticket</a></li>
# <li><a href="?pageView=traderscockpit-product-details" title="TradersCockpit Product Details">TradersCockpit Product Details</a></li>
# <li><a href="http://traderscockpit.uservoice.com/knowledgebase" target="_blank">FAQ / KnowledgeBase</a></li>
# <li><a href="?pageView=technical-analysis-training-videos">FAQ Videos</a></li>
# <!-- <li><a href="?pageView=give-testimonial">Give Testimonial</a></li> -->
# <li><a href="?pageView=mobile-verification">Mobile Verification</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="markets-menu specific-menu">
# <div class="row">
# <div class="col-sm-3 col-md-3 col-lg-3">
# <a class="nav-level-1"><img class="secLevelIcon" src="/v2/img/nseToday_white.png"/>Markets</a>
# <ul>
# <li><a href="?pageView=india-stock-market-analysis" title="NSE Today">Nse Today</a></li>
# <li><a href="?pageView=nse-top-gainers">Top Gainers</a></li>
# <li><a href="?pageView=nse-top-losers">Top Losers</a></li>
# <li><a href="?pageView=nse-dynamic-heatmap">Dynamic HeatMap</a></li>
# <li><a href="?pageView=live-nse-indices-watch">Live Indices Watch</a></li>
# <li><a href="?pageView=nse-concurrent-gainers">Concurrent Gainers / Losers</a></li>
# </ul>
# </div>
# <div class="col-sm-3 col-md-3 col-lg-3">
# <a class="nav-level-1"><img class="secLevelIcon" src="/v2/img/foAnalysis_white.png"/>FO Analysis</a>
# <ul>
# <li><a href="?pageView=long-positions-fresh-longs">Fresh Longs</a></li>
# <li><a href="?pageView=short-sell-fresh-shorts">Fresh Shorts</a></li>
# <li><a href="?pageView=short-covering">Short Covering</a></li>
# <li><a href="?pageView=long-unwinding">Long Unwinding</a></li>
# <li><a href="?pageView=symbol-analysis&amp;company=NIFTY&amp;symbol=NIFTY&amp;stock-analysis=NIFTY-end-of-day-stock-analysis&amp;tickType=0">Nifty Analysis</a></li>
# <li><a href="?pageView=nse-futures-spot-arbitrage">Futures Spot Arbitrage</a></li>
# </ul>
# </div>
# <div class="col-sm-3 col-md-3 col-lg-3">
# <a class="nav-level-1"><img class="secLevelIcon" src="/v2/img/advanceDecline_white.png"/>Advances/Declines (AD)</a>
# <ul>
# <li><a href="?pageView=live-nse-advance-decline-ratio-chart">Live AD Ratio Chart</a></li>
# <li><a href="?pageView=historical-nse-advance-decline-ratio-chart-and-nse-adline-chart">Historical AD Ratio Chart</a></li>
# </ul>
# <a class="nav-level-1" href="#"><img class="secLevelIcon" src="/v2/img/FII_DII_white.png"/>FII / DII</a>
# <ul>
# <li><a href="?pageView=fii-dii-activity">FII / DII Chart</a></li>
# <li><a href="?pageView=fii-dii-in-india">FII / DII Activities</a></li>
# </ul>
# </div>
# <div class="col-sm-3 col-md-3 col-lg-3">
# <a class="nav-level-1" href="#"><img class="secLevelIcon" src="/v2/img/misc_white.png"/>Misc</a>
# <ul>
# <li><a href="?pageView=52-week-high">52 Week High</a></li>
# <li><a href="?pageView=52-week-low">52 Week Low</a></li>
# <!-- <li><a href="?pageView=latest-quarterly-results">Quarterly Results</a></li>-->
# <li><a href="?pageView=latest-corporate-announcements">Corporate Announcements</a></li>
# <li><a href="?pageView=delivery-percentage">Delivery Percentage</a></li>
# <li><a href="?pageView=historical-delivery-details">Delivery Details</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="dashboardx-menu specific-menu">
# <div class="row">
# <div class="col-sm-3 col-md-3 col-lg-3">
# <a class="nav-level-1"><img class="secLevelIcon" src="/v2/img/myTradersCockpit_white.png"/>Ready to Use</a>
# <ul>
# <li><a href="?pageView=intraday-dashboard">Stock Intraday Dashboard</a></li>
# <li><a href="?pageView=tc-intraday-strategy-dashboards">Intraday Trading System</a></li>
# <li><a href="?pageView=tc-strategy-dashboards">Short Term Trading System</a></li>
# <li><a href="?pageView=relative-stock-strength&amp;symbol=RELIANCE&amp;score-analysis=RELIANCE-sector-score-analysis">Stock Technical Score</a></li>
# <li><a href="?pageView=popular-technical-stock-screeners">Pre-Created Screeners</a></li>
# <li><a href="?pageView=custom-options-screener-dashboard">Monthly Options Dashboard</a></li>
# <li><a href="?pageView=weekly-options-screener-dashboard">Weekly Options Dashboard</a></li>
# </ul>
# </div>
# <div class="col-sm-3 col-md-3 col-lg-3">
# <a class="nav-level-1"><img class="secLevelIcon" src="/v2/img/myTradersCockpit_white.png"/>Technical Dashboards</a>
# <ul>
# <li><a href="?pageView=custom-rt-screener-dashboard">TC 3.15pm Dashboard</a></li>
# <li><a href="?pageView=popular-technical-stock-screeners">TC Multi Screening Dashboard</a></li>
# <li><a href="?pageView=intraday-wl-dashboard">My WatchGroup Intraday Dashboard</a></li>
# <li><a href="?pageView=iv-dashboard">IV Scanner Dashboard</a></li>
# </ul>
# </div>
# <div class="col-sm-3 col-md-3 col-lg-3">
# <a class="nav-level-1"><img class="secLevelIcon" src="/v2/img/myTradersCockpit_white.png"/>SmartCase</a>
# <ul>
# <li><a href="?pageView=tc-smartcase-one">Trading Smartcase - 3 PM</a></li>
# <li><a href="?pageView=tc-smartcase-eod">Trading Smartcase EOD</a></li>
# <li><a href="?pageView=tc-smartcase-weekly">Investing SmartCase</a></li>
# </ul>
# </div>
# <div class="col-sm-3 col-md-3 col-lg-3">
# <a class="nav-level-1"><img class="secLevelIcon" src="/v2/img/myTradersCockpit_white.png"/>EOD/Weekly Technical Dashboard</a>
# <ul>
# <li><a href="?pageView=custom-screener-dashboard">TC EOD Screening Dashboard</a></li>
# <li><a href="?pageView=custom-weekly-screener-dashboard">Weekly Screening Dashboard</a></li>
# <li><a href="?pageView=custom-investment-dashboard">TC Investment Dashboard</a></li>
# <li><a href="?pageView=intraday-historical-dashboard">Historical IntraDay Dashboard</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="chartx-menu specific-menu">
# <div class="row">
# <div class="col-sm-3 col-md-3 col-lg-3">
# <a class="nav-level-1"><img class="secLevelIcon" src="/v2/img/mobileFriendlyCharts_white.png"/>Interactive Charts (Mobile Friendly)</a>
# <ul>
# <li><a href="?pageView=nse-interactive-technical-charts" title="Interactive NSE Technical Charts for Smart Phones">Interactive Technical Charts</a></li>
# <li><a href="?pageView=free-nse-intraday-charts" title="Free NSE IntraDay charts">Free NSE IntraDay Charts</a></li>
# <li><a href="?pageView=new-advanced-charts" title="NSE Advanced Charts with TrendLines and Proprietary Indicators">Advanced (Proprietary Indicators) Charts</a></li>
# <li><a href="?pageView=renko-chart" title="NIFTY Renko Chart and PF Chart">Renko, Heikin Ashi and P&amp;F Chart</a></li>
# <li><a href="?pageView=nse-spread-chart" title="NSE Spread Charts">NSE Spread Chart</a></li>
# <li><a href="?pageView=forex-charts" title="Interactive Forex Charts">Interactive Forex Charts</a></li>
# </ul>
# </div>
# <div class="col-sm-3 col-md-3 col-lg-3">
# <a class="nav-level-1"><img class="secLevelIcon" src="/v2/img/liveInteractiveCharts_white.png"/>Live Technical Charts(Java)</a>
# <ul>
# <li><a href="?pageView=realtime-technical-analysis-chart" title="Real Time Technical Analysis Charts">Free Cash Charts<span class="menu-support">(Intraday/Daily/Weekly)</span></a></li>
# <li><a href="?pageView=futures-realtime-technical-analysis-chart" title="Live Futures Technical Analysis Chart">Futures Technical Charts (IntraDay/Daily/Weekly)<span class="menu-support">(Intraday/Daily/Weekly)</span></a></li>
# <li><a href="?pageView=options-realtime-technical-analysis-chart" title="Live Options Technical Analysis Chart">Options Technical Charts (IntraDay/Daily/Weekly)<span class="menu-support">(Intraday/Daily/Weekly)</span></a></li>
# <li><a href="?pageView=continuous-live-nse-futures-technical-charts" title="Live Continuous Futures Technical Analysis Chart">Continuous Futures Charts</a></li>
# </ul>
# </div>
# <div class="col-sm-3 col-md-3 col-lg-3">
# <a class="nav-level-1"><img class="secLevelIcon" src="/v2/img/miscCharts_white.png"/>Misc Charts</a>
# <ul>
# <li><a href="?pageView=nse-dynamic-heatmap" title="NSE Dynamic Heatmap">Dynamic HeatMap</a></li>
# <li><a href="?pageView=live-nse-advance-decline-ratio-chart" title="Live NSE Advance Decline Ratio Chart">Live AD Ratio Chart</a></li>
# <li><a href="?pageView=india-volatility-index-chart-vs-nifty-chart" title="IndiaVIX V/S NIFTY Chart">India VIX v/s NIFTY Chart</a></li>
# <li><a href="?pageView=fii-dii-activity" title="FII &amp; DII v/s Nifty Chart">FII &amp; DII Chart</a></li>
# <li><a href="?pageView=nifty-pe-ratio-chart-and-pb-dividend-yield-chart" title="NSE Indices PE Charts and Dividend Yield Chart">PE, PB, Div. Yield Chart</a></li>
# ...
# <td>748.9</td>
# <td style="color: #ff0000">-3.31</td>
# <td><a href=" https://traderscockpit.com/?pageView=intraday-dashboard&amp;symbol=COROMANDEL">ID Dashboard</a> </td>
# <td>774.55</td>
# <td>774.9</td>
# <td>746.25</td>
# <td>774.55</td>
# <td>600732</td>
# <td>753.98</td>
# <td style="width:101px;padding: 0;margin: 0;"><img src="http://chart.apis.google.com/chart?chf=bg,s,FFFFFF&amp;chs=100x20&amp;cht=ls&amp;chco=FF0000&amp;chds=742.35,772.7&amp;chd=t:767.7,767.3,763.95,765.95,764.3,764.1,764.15,763.55,763.8,763.8,764.5,761.95,761.2,760.55,759.05,757.4,759.5,759.4,760.55,760.0,759.15,759.2,758.0,758.0,756.05,756.0,755.65,755.2,755.45,757.0,755.9,756.3,756.6,755.85,756.9,755.0,755.0,752.1,753.65,753.6,752.2,752.0,752.0,752.0,752.0,752.0,752.0,752.0,751.85,751.8,751.9,752.0,751.0,750.9,749.75,749.95,748.95,749.65,748.55,748.5,748.5,748.45,747.35,748.5,748.4,748.5,748.5,748.5,748.25,748.0,747.75,747.45,750.0,748.65,748.7&amp;chls=1"/></td>
# </tr>
# <tr class="even">
# <td><a href="/AnalysisView?action=symbolAnalysis&amp;symbolFilter=GILLETTE" title="cssbody=[boxover_body] fadespeed=[0.06] singleclickstop=[on] fade=[on] cssheader=[boxover_header] body=[&lt;iframe src='/charts/index.jsp?sym=GILLETTE&amp;w=620&amp;h=250&amp;cs=1&amp;sklr=20&amp;ct=3' width='650' height='300' scrolling='no' frameborder='no' marginheight='0' marginwidth='0'  &gt;&amp;lt/iframe&gt;]"><img border="0" height="14" src="/images/chart_small.gif" style="margin-right:3px;" width="14"/></a><a href="/AnalysisView?action=symbolAnalysis&amp;symbolFilter=GILLETTE&amp;stock-analysis=GILLETTE-end-of-day-stock-analysis&amp;tickType=0" title="Click to view GILLETTE Live Analysis">GILLETTE</a></td>
# <td>5689.75</td>
# <td style="color: #ff0000">-3.56</td>
# <td><a href=" https://traderscockpit.com/?pageView=intraday-dashboard&amp;symbol=GILLETTE">ID Dashboard</a> </td>
# <td>5861.0</td>
# <td>5895.0</td>
# <td>5490.1</td>
# <td>5900.05</td>
# <td>16491</td>
# <td>5721.02</td>
# <td style="width:101px;padding: 0;margin: 0;"><img src="http://chart.apis.google.com/chart?chf=bg,s,FFFFFF&amp;chs=100x20&amp;cht=ls&amp;chco=FF0000&amp;chds=5675.0,5883.5&amp;chd=t:5870.05,5870.2,5850.45,5854.8,5859.95,5860.0,5870.0,5870.05,5870.0,5864.45,5878.5,5875.0,5753.05,5742.4,5738.95,5747.45,5744.75,5747.9,5750.0,5732.8,5737.9,5730.95,5734.95,5730.0,5722.45,5729.05,5723.3,5720.7,5718.75,5721.95,5721.85,5707.65,5708.95,5728.0,5725.0,5745.0,5750.0,5747.75,5748.8,5729.95,5725.95,5741.55,5730.8,5748.45,5749.0,5750.0,5747.0,5744.9,5739.75,5741.85,5749.95,5753.0,5754.9,5761.0,5766.0,5762.7,5759.95,5753.6,5757.95,5757.0,5747.0,5742.0,5749.9,5734.9,5724.95,5723.25,5715.0,5710.35,5686.1,5711.0,5680.65,5682.95,5685.0,5688.95,5680.0&amp;chls=1"/></td>
# </tr>
# <tr class="odd">
# <td><a href="/AnalysisView?action=symbolAnalysis&amp;symbolFilter=REDINGTON" title="cssbody=[boxover_body] fadespeed=[0.06] singleclickstop=[on] fade=[on] cssheader=[boxover_header] body=[&lt;iframe src='/charts/index.jsp?sym=REDINGTON&amp;w=620&amp;h=250&amp;cs=1&amp;sklr=20&amp;ct=3' width='650' height='300' scrolling='no' frameborder='no' marginheight='0' marginwidth='0'  &gt;&amp;lt/iframe&gt;]"><img border="0" height="14" src="/images/chart_small.gif" style="margin-right:3px;" width="14"/></a><a href="/AnalysisView?action=symbolAnalysis&amp;symbolFilter=REDINGTON&amp;stock-analysis=REDINGTON-end-of-day-stock-analysis&amp;tickType=0" title="Click to view REDINGTON Live Analysis">REDINGTON</a></td>
# <td>184.0</td>
# <td style="color: #ff0000">-3.59</td>
# <td><a href=" https://traderscockpit.com/?pageView=intraday-dashboard&amp;symbol=REDINGTON">ID Dashboard</a> </td>
# <td>192.3</td>
# <td>192.8</td>
# <td>182.05</td>
# <td>190.85</td>
# <td>433169</td>
# <td>185.66</td>
# <td style="width:101px;padding: 0;margin: 0;"><img src="http://chart.apis.google.com/chart?chf=bg,s,FFFFFF&amp;chs=100x20&amp;cht=ls&amp;chco=FF0000&amp;chds=178.05,192.9&amp;chd=t:187.6,187.9,185.75,186.65,185.5,186.8,186.35,186.15,186.65,186.9,186.05,186.2,186.85,187.0,186.85,186.0,186.35,186.1,186.0,185.75,186.1,185.85,184.5,185.3,185.75,185.5,185.7,185.6,185.25,185.35,185.35,185.5,185.6,185.1,186.05,185.25,185.65,185.25,185.2,184.9,185.0,185.15,185.15,185.35,185.2,185.6,185.8,185.95,185.95,185.85,185.1,184.85,184.85,185.05,185.25,184.5,185.55,185.55,185.35,185.0,185.5,185.2,185.3,185.1,185.1,183.8,183.75,184.0,184.2,184.25,184.75,184.85,184.05,183.05,183.5&amp;chls=1"/></td>
# </tr>
# <tr class="even">
# <td><a href="/AnalysisView?action=symbolAnalysis&amp;symbolFilter=METROPOLIS" title="cssbody=[boxover_body] fadespeed=[0.06] singleclickstop=[on] fade=[on] cssheader=[boxover_header] body=[&lt;iframe src='/charts/index.jsp?sym=METROPOLIS&amp;w=620&amp;h=250&amp;cs=1&amp;sklr=20&amp;ct=3' width='650' height='300' scrolling='no' frameborder='no' marginheight='0' marginwidth='0'  &gt;&amp;lt/iframe&gt;]"><img border="0" height="14" src="/images/chart_small.gif" style="margin-right:3px;" width="14"/></a><a href="/AnalysisView?action=symbolAnalysis&amp;symbolFilter=METROPOLIS&amp;stock-analysis=METROPOLIS-end-of-day-stock-analysis&amp;tickType=0" title="Click to view METROPOLIS Live Analysis">METROPOLIS</a></td>
# <td>2159.65</td>
# <td style="color: #ff0000">-3.64</td>
# <td><a href=" https://traderscockpit.com/?pageView=intraday-dashboard&amp;symbol=METROPOLIS">ID Dashboard</a> </td>
# <td>2219.0</td>
# <td>2265.5</td>
# <td>2142.05</td>
# <td>2241.2</td>
# <td>117841</td>
# <td>2201.05</td>
# <td style="width:101px;padding: 0;margin: 0;"><img src="http://chart.apis.google.com/chart?chf=bg,s,FFFFFF&amp;chs=100x20&amp;cht=ls&amp;chco=FF0000&amp;chds=2144.95,2259.05&amp;chd=t:2254.05,2254.0,2230.05,2234.55,2229.85,2224.55,2225.45,2235.85,2231.1,2233.55,2229.65,2215.45,2217.3,2219.95,2223.3,2223.9,2219.05,2220.9,2216.9,2211.05,2208.7,2209.4,2204.75,2203.0,2191.55,2193.9,2193.3,2196.05,2190.0,2189.55,2186.0,2189.0,2189.1,2194.45,2198.95,2200.9,2197.55,2189.25,2181.0,2184.8,2179.2,2180.0,2176.8,2179.95,2179.0,2179.95,2176.85,2178.8,2165.65,2171.0,2175.0,2170.9,2169.85,2163.0,2169.8,2168.65,2167.0,2165.0,2165.0,2165.0,2165.0,2165.0,2163.15,2164.95,2162.65,2165.0,2164.95,2165.0,2165.0,2165.0,2162.25,2164.3,2156.35,2149.95,2163.0&amp;chls=1"/></td>
# </tr>
# <tr class="odd">
# <td><a href="/AnalysisView?action=symbolAnalysis&amp;symbolFilter=BRIGADE" title="cssbody=[boxover_body] fadespeed=[0.06] singleclickstop=[on] fade=[on] cssheader=[boxover_header] body=[&lt;iframe src='/charts/index.jsp?sym=BRIGADE&amp;w=620&amp;h=250&amp;cs=1&amp;sklr=20&amp;ct=3' width='650' height='300' scrolling='no' frameborder='no' marginheight='0' marginwidth='0'  &gt;&amp;lt/iframe&gt;]"><img border="0" height="14" src="/images/chart_small.gif" style="margin-right:3px;" width="14"/></a><a href="/AnalysisView?action=symbolAnalysis&amp;symbolFilter=BRIGADE&amp;stock-analysis=BRIGADE-end-of-day-stock-analysis&amp;tickType=0" title="Click to view BRIGADE Live Analysis">BRIGADE</a></td>
# <td>267.35</td>
# <td style="color: #ff0000">-3.78</td>
# <td><a href=" https://traderscockpit.com/?pageView=intraday-dashboard&amp;symbol=BRIGADE">ID Dashboard</a> </td>
# <td>281.0</td>
# <td>281.0</td>
# <td>262.1</td>
# <td>277.85</td>
# <td>561864</td>
# <td>267.94</td>
# <td style="width:101px;padding: 0;margin: 0;"><img src="http://chart.apis.google.com/chart?chf=bg,s,FFFFFF&amp;chs=100x20&amp;cht=ls&amp;chco=FF0000&amp;chds=259.8,282.15&amp;chd=t:277.15,275.7,275.3,275.25,274.5,274.6,274.05,274.95,274.1,274.2,272.4,271.95,271.6,271.0,273.55,273.45,273.0,272.2,272.65,272.5,272.05,269.95,269.05,267.9,266.0,266.95,266.35,267.05,267.1,267.7,267.05,268.1,267.6,267.25,267.2,267.65,267.65,268.4,268.5,268.6,267.65,267.65,267.65,267.45,267.55,267.55,267.6,266.5,267.25,267.3,267.15,267.0,266.35,266.4,266.1,266.05,266.05,265.1,265.2,265.0,264.8,265.6,265.05,266.0,267.05,267.95,269.6,267.0,266.9,267.4,267.85,267.75,268.5,267.45,265.1&amp;chls=1"/></td>
# </tr>
# <tr class="even">
# <td><a href="/AnalysisView?action=symbolAnalysis&amp;symbolFilter=APLAPOLLO" title="cssbody=[boxover_body] fadespeed=[0.06] singleclickstop=[on] fade=[on] cssheader=[boxover_header] body=[&lt;iframe src='/charts/index.jsp?sym=APLAPOLLO&amp;w=620&amp;h=250&amp;cs=1&amp;sklr=20&amp;ct=3' width='650' height='300' scrolling='no' frameborder='no' marginheight='0' marginwidth='0'  &gt;&amp;lt/iframe&gt;]"><img border="0" height="14" src="/images/chart_small.gif" style="margin-right:3px;" width="14"/></a><a href="/AnalysisView?action=symbolAnalysis&amp;symbolFilter=APLAPOLLO&amp;stock-analysis=APLAPOLLO-end-of-day-stock-analysis&amp;tickType=0" title="Click to view APLAPOLLO Live Analysis">APLAPOLLO</a></td>
# <td>1326.75</td>
# <td style="color: #ff0000">-5.29</td>
# <td><a href=" https://traderscockpit.com/?pageView=intraday-dashboard&amp;symbol=APLAPOLLO">ID Dashboard</a> </td>
# <td>1423.0</td>
# <td>1440.0</td>
# <td>1296.9</td>
# <td>1400.85</td>
# <td>291355</td>
# <td>1338.64</td>
# <td style="width:101px;padding: 0;margin: 0;"><img src="http://chart.apis.google.com/chart?chf=bg,s,FFFFFF&amp;chs=100x20&amp;cht=ls&amp;chco=FF0000&amp;chds=1300.0,1429.35&amp;chd=t:1421.35,1416.4,1424.35,1399.95,1396.1,1389.0,1362.4,1373.0,1371.85,1373.15,1373.0,1364.0,1364.0,1366.7,1364.1,1363.2,1359.15,1343.1,1345.6,1346.0,1342.1,1323.0,1326.0,1326.1,1342.4,1341.25,1328.4,1321.85,1324.75,1326.9,1327.5,1325.1,1322.55,1327.0,1331.0,1332.3,1332.15,1325.0,1324.5,1324.9,1323.85,1324.8,1323.0,1322.3,1323.0,1323.5,1324.95,1325.0,1323.6,1323.8,1324.0,1312.75,1316.3,1314.6,1314.25,1308.0,1307.7,1305.0,1305.0,1311.0,1313.0,1317.0,1322.45,1319.5,1321.0,1318.0,1314.5,1312.4,1318.65,1326.7,1332.0,1333.0,1327.05,1324.0,1326.0&amp;chls=1"/></td>
# </tr>
# </table>
# </td>
# <td style="vertical-align: top;">
# <table style="width:100%">
# <tr>
# <td>
# <script type="text/javascript">
#     setTimeout("window.location = window.location;", 120000);
# </script>
# <script type="text/javascript">
#     <!--
#     google_ad_client = "ca-pub-3536434264887104";
#     /* Chart Vertical Ad */
#     google_ad_slot = "5912190377";
#     google_ad_width = 160;
#     google_ad_height = 600;
#     //-->
#     </script>
# <script src="http://pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript">
# </script>
# </td>
# </tr>
# <tr>
# <td>
# <script type="text/javascript">
#     setTimeout("window.location = window.location;", 120000);
# </script>
# <script type="text/javascript">
#     <!--
#     google_ad_client = "ca-pub-3536434264887104";
#     /* Chart Vertical Ad */
#     google_ad_slot = "5912190377";
#     google_ad_width = 160;
#     google_ad_height = 600;
#     //-->
#     </script>
# <script src="http://pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript">
# </script>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# <script type="text/javascript">
#             updateAdvancesDeclines('400','98','3');
#         </script>
# </div>
# </div>
# </div>
# </div>
# <!--
# footer comes here
#  -->
# <div class="container-fluid footer-container">
# <div class="container">
# <div class="row">
# <div class="col-sm-3 col-md-3 col-lg-3">
# <div class="footer-title">Company</div>
# <div class="footer-link"><a href="?pageView=about-us" title="About Us">About Us</a></div>
# <div class="footer-link"><a href="?pageView=media-coverage">Media Coverage</a></div>
# <div class="footer-link"><a href="?pageView=whyus" title="Why Us?">Why Us?</a></div>
# <div class="footer-link"><a href="?pageView=job-openings">We Are Hiring</a></div>
# </div>
# <div class="col-sm-3 col-md-3 col-lg-3">
# <div class="footer-title">Support</div>
# <div class="footer-link"><a href="http://traderscockpit.uservoice.com/knowledgebase" target="_blank">Feedback</a></div>
# <div class="footer-link"><a href="?pageView=contact-us" title="Contact Us">Contact Us</a></div>
# </div>
# <div class="col-sm-3 col-md-3 col-lg-3">
# <div class="footer-title">Trust</div>
# <div class="footer-link"><a href="?pageView=tandc" title="Terms and Conditions">Terms &amp; Conditions</a></div>
# <div class="footer-link"><a href="?pageView=privacy-policy" title="Privacy Policy">Privacy Policy</a></div>
# <div class="footer-link"><a href="?pageView=randc" title="Refund and Cancellation Policy">Refund Policy</a></div>
# <div class="footer-link"><a href="?pageView=disclaimer" title="Disclaimer">Disclaimer</a></div>
# </div>
# <div class="col-sm-3 col-md-3 col-lg-3">
# <div class="footer-title">Knowledge</div>
# <div class="footer-link"><a href="http://traderscockpit.uservoice.com/" target="_blank">FAQ</a></div>
# </div>
# </div>
# <div class="row">
# <div class="col-sm-12 col-lg-12 col-md-12">
# <p class="copyright">Copyright © 2020 Gumption Labs Software Solutions Pvt. Ltd. | All Rights</p>
# </div>
# </div>
# </div>
# </div>
# <!--start of vcita code -->
# <script charset="utf-8" type="text/javascript">
#     var vcHost = document.location.protocol == "https:" ? "https:" : "http:";
#     document.write(unescape("%3Cscript src='" + vcHost + "//www.vcita.com/v/398cb9ab/loader.js' type='text/javascript'%3E%3C/script%3E"));
# </script>
# <noscript>
# <div style="position:fixed;right:10px;bottom:10px;font-size:12px;color:#62656a;font-family:Arial, sans-serif">
# <p>
#             Contact Traders Cockpit</p>
# <p>
# <a href="http://www.vcita.com/meeting_scheduler?v=398cb9ab" target="_blank">Set a Meeting</a> or
#             <a href="http://www.vcita.com/contact_page?v=398cb9ab" target="_blank">Send a Message</a>
# </p>
# </div>
# </noscript>
# <!--end of vcita code -->
# <!-- BEGIN JIVOSITE CODE {literal}
# <script type='text/javascript'>
#     (function(){ var widget_id = 'ULCPLv2HnP';
#         var s = document.createElement('script'); s.type = 'text/javascript'; s.async = true; s.src = '//code.jivosite.com/script/geo-widget/'+widget_id; var ss = document.getElementsByTagName('script')[0]; ss.parentNode.insertBefore(s, ss);})();
# </script> -->
# <!--Start of Tawk.to Script-->
# <script type="text/javascript">
# var Tawk_API=Tawk_API||{}, Tawk_LoadStart=new Date();
# (function(){
# var s1=document.createElement("script"),s0=document.getElementsByTagName("script")[0];
# s1.async=true;
# s1.src='https://embed.tawk.to/58c7f66093cfd355720b9275/default';
# s1.charset='UTF-8';
# s1.setAttribute('crossorigin','*');
# s0.parentNode.insertBefore(s1,s0);
# })();
# </script>
# <!--End of Tawk.to Script-->
# <script type="text/javascript">
#     $(document).ready(function() {
#         $(".symbolChartiframe").fancybox({
#             'width'				: 960,
#             'height'			: 800,
#             'autoScale'			: false,
#             'transitionIn'		: 'none',
#             'transitionOut'		: 'none',
#             'type'				: 'iframe'
#         });
#     });
#
#     $(document).ready(function() {
#         $(".wlFrame").fancybox({
#             'width'				: 350,
#             'height'			: 300,
#             'autoScale'			: false,
#             'transitionIn'		: 'none',
#             'transitionOut'		: 'none',
#             'type'				: 'iframe',
#             'title'            :'WatchList'
#         });
#     });
#
#     $(document).ready(function () {
#         $(".recommendationFrame").fancybox({
#             'width':740,
#             'height':650,
#             'autoScale':false,
#             'transitionIn':'none',
#             'transitionOut':'none',
#             'type':'iframe'
#         });
#     });
#
#
#     $(document).ready(function() {
#         $(".screenerFrame").fancybox({
#             'width'				: 450,
#             'height'			: 550,
#             'autoScale'			: false,
#             'transitionIn'		: 'none',
#             'transitionOut'		: 'none',
#             'type'				: 'iframe',
#             'title'            :'Stock Screener',
#             onClosed : function(){
#                 window.location = window.location;
#             }
#         });
#         $(".demoVideo").fancybox({
#             'width'				: 1039,
#             'height'			: 600,
#             'autoScale'			: false,
#             'transitionIn'		: 'none',
#             'transitionOut'		: 'none',
#             'type'				: 'iframe'
#         });
#     });
#
#
# </script>
# <script src="/js/google-analytics.js" type="text/javascript"></script>
# </body>
# </html>

# %% [markdown]
# #getting the table

# %%
page
# Out:
# <Response [200]>

# %%
table1=soup.find('table', {'class': 'greenTable'})

# %%
header1=[]
for i in table1.find_all('tr'):
    title=i.text.strip()
    title = title.replace('\n', ' ')
    title = title.split(" ", 1)
    title = title[0]
    #ep = "\"
    #itle = title.split(" '\  )
    header1.append(title)

# %%
header1
# Out:
# ['Index',
#  'NIFTY',
#  'ASTRAZEN',
#  'CAPLIPOINT',
#  'DISHTV',
#  'FCONSUMER',
#  'ADANITRANS',
#  'MMTC',
#  'JKTYRE',
#  'IBREALEST',
#  'GRAPHITE',
#  'NATIONALUM',
#  'JSWSTEEL',
#  'MIDHANI',
#  'IDEA',
#  'SWSOLAR',
#  'HEG',
#  'JINDALSTEL',
#  'ADANIENT',
#  'GSFC',
#  'HINDALCO',
#  'SPARC',
#  'GMDCLTD',
#  'WELCORP',
#  'KTKBANK',
#  'SAIL',
#  'STLTECH',
#  'TATASTLBSL',
#  'HERITGFOOD',
#  'TATASTEEL',
#  'UJJIVAN',
#  'FLUOROCHEM',
#  'MHRIL',
#  'SRF',
#  'IOB',
#  'GAEL',
#  'TATACOMM',
#  'HSCL',
#  'IIFLWAM',
#  'APOLLOTYRE',
#  'SOUTHBANK',
#  'MANAPPURAM',
#  'JYOTHYLAB',
#  'ORIENTREF',
#  'SHILPAMED',
#  'SUPRAJIT',
#  'GREAVESCOT',
#  'BEML',
#  'ADANIGREEN',
#  'EDELWEISS',
#  'HINDCOPPER',
#  'HFCL',
#  'SBICARD',
#  'RAIN',
#  'RATNAMANI',
#  'FRETAIL',
#  'CENTRALBK',
#  'PNBHOUSING',
#  'SHRIRAMCIT',
#  'ADANIPORTS',
#  'WELSPUNIND',
#  'IRB',
#  'CARERATING',
#  'THYROCARE',
#  'KOLTEPATIL',
#  'ATUL',
#  'JUSTDIAL',
#  'UJJIVANSFB',
#  'LUXIND',
#  'BHEL',
#  'BOMDYEING',
#  'MOTHERSUMI',
#  'NAVNETEDUL',
#  'GICRE',
#  'NETWORK18',
#  'CHALET',
#  'VAIBHAVGBL',
#  'IIFL',
#  'IEX',
#  'INDUSTOWER',
#  'DELTACORP',
#  'ASTRAL',
#  'PNB',
#  'RBLBANK',
#  'IBULHSGFIN',
#  'PHILIPCARB',
#  'SPICEJET',
#  'ASHOKLEY',
#  'HAL',
#  'UCOBANK',
#  'DCAL',
#  'INDUSINDBK',
#  'FEDERALBNK',
#  'VAKRANGEE',
#  'GLENMARK',
#  'DHANUKA',
#  'GNFC',
#  'J&KBANK',
#  'ORIENTCEM',
#  'BALMLAWRIE',
#  'JAICORPLTD',
#  'CGCL',
#  'L&TFH',
#  'SIS',
#  'FSL',
#  'MAHINDCIE',
#  'VARROC',
#  'TATACHEM',
#  'MOIL',
#  'BSOFT',
#  'SRTRANSFIN',
#  'BANDHANBNK',
#  'AARTIIND',
#  'AARTIDRUGS',
#  'ALOKINDS',
#  'WOCKPHARMA',
#  'GAIL',
#  'ELGIEQUIP',
#  'JINDALSAW',
#  'BAJAJCON',
#  'JSL',
#  'CUB',
#  'DCMSHRIRAM',
#  'AKZOINDIA',
#  'AUBANK',
#  'JSWENERGY',
#  'BASF',
#  'SONATSOFTW',
#  'NOCIL',
#  'MAHSEAMLES',
#  'RELAXO',
#  'BBTC',
#  'JKPAPER',
#  'MAHABANK',
#  'SCI',
#  'MRPL',
#  'ISEC',
#  'GRSE',
#  'GMMPFAUDLR',
#  'INDIAMART',
#  'BANKINDIA',
#  'NH',
#  'GPPL',
#  'ZEEL',
#  'FINPIPE',
#  'KOTAKBANK',
#  'TATAELXSI',
#  'BHARATFORG',
#  'CHENNPETRO',
#  'GMRINFRA',
#  'KSCL',
#  'HUHTAMAKI',
#  'HUDCO',
#  'RAJESHEXPO',
#  'CYIENT',
#  'GRANULES',
#  'GULFOILLUB',
#  'RALLIS',
#  'JSLHISAR',
#  'IGL',
#  'EIHOTEL',
#  'CANBK',
#  'HINDZINC',
#  'M&MFIN',
#  'SYNGENE',
#  'TATAMTRDVR',
#  'NCC',
#  'AFFLE',
#  'JTEKTINDIA',
#  'DBL',
#  'TCNSBRANDS',
#  'BIRLACORPN',
#  'MOTILALOFS',
#  'UFLEX',
#  'DHANI',
#  'CEATLTD',
#  'LTTS',
#  'UNIONBANK',
#  'SCHNEIDER',
#  'NBCC',
#  'GUJALKALI',
#  'RAMCOCEM',
#  'MFSL',
#  'IDFCFIRSTB',
#  'TATACOFFEE',
#  'ULTRACEMCO',
#  'STARCEMENT',
#  'BAJFINANCE',
#  'HATSUN',
#  'ADVENZYMES',
#  'BLISSGVS',
#  'HEIDELBERG',
#  'NFL',
#  'APLLTD',
#  'ESABINDIA',
#  'NMDC',
#  'SYMPHONY',
#  'PRSMJOHNSN',
#  'ALEMBICLTD',
#  'AXISBANK',
#  'BPCL',
#  'INGERRAND',
#  'BSE',
#  'SUNPHARMA',
#  'LEMONTREE',
#  'ONGC',
#  'KEC',
#  'ICICIBANK',
#  'RCF',
#  'KARURVYSYA',
#  'FINCABLES',
#  'HCLTECH',
#  'BANKBARODA',
#  'CESC',
#  'SUZLON',
#  'NATCOPHARM',
#  'RAYMOND',
#  'SOBHA',
#  'TATAMOTORS',
#  'BAJAJ-AUTO',
#  'ITI',
#  'GARFIBRES',
#  'TVTODAY',
#  'RVNL',
#  'SUNDARMFIN',
#  'ABCAPITAL',
#  'DMART',
#  'EIDPARRY',
#  'ORIENTELEC',
#  'DBCORP',
#  'UPL',
#  'ENGINERSIN',
#  'IRCON',
#  'POLYMED',
#  'LT',
#  'NAM-INDIA',
#  'TATACONSUM',
#  'SBIN',
#  'TATAPOWER',
#  'INDIANB',
#  'DCBBANK',
#  'SUNTV',
#  'SHREECEM',
#  'DLF',
#  'RITES',
#  'BAJAJELEC',
#  'KAJARIACER',
#  'BDL',
#  'PERSISTENT',
#  'DRREDDY',
#  'TV18BRDCST',
#  'FORTIS',
#  'M&M',
#  'HDFCAMC',
#  'PEL',
#  'INDIACEM',
#  'HEROMOTOCO',
#  'LTI',
#  'IOC',
#  'CSBBANK',
#  'POWERGRID',
#  'JAMNAAUTO',
#  'SANOFI',
#  'BAJAJHLDNG',
#  'PETRONET',
#  'KALPATPOWR',
#  'COALINDIA',
#  'JUBLFOOD',
#  'PTC',
#  'GODFRYPHLP',
#  'HDFC',
#  'BATAINDIA',
#  'JKLAKSHMI',
#  'HINDPETRO',
#  'INDHOTEL',
#  'NTPC',
#  'SEQUENT',
#  'BAJAJFINSV',
#  'LAXMIMACH',
#  'INFY',
#  'RECLTD',
#  'POLYCAB',
#  'EXIDEIND',
#  'ICRA',
#  'IDBI',
#  'TIMKEN',
#  'POWERINDIA',
#  'SWARAJENG',
#  'KEI',
#  'COCHINSHIP',
#  'SWANENERGY',
#  'ALKYLAMINE',
#  'LICHSGFIN',
#  'GSPL',
#  'TRIDENT',
#  'MGL',
#  'MRF',
#  'PRESTIGE',
#  'MAHSCOOTER',
#  'EICHERMOT',
#  'JMFINANCIL',
#  'TASTYBITE',
#  'OIL',
#  'AVANTIFEED',
#  'SUPPETRO',
#  'PVR',
#  'SUDARSCHEM',
#  'MARUTI',
#  'RELIANCE',
#  'SCHAEFFLER',
#  'LAURUSLABS',
#  'RADICO',
#  'TORNTPOWER',
#  'LALPATHLAB',
#  'AEGISCHEM',
#  'MINDACORP',
#  'NIACL',
#  'POLYPLEX',
#  'VMART',
#  'NHPC',
#  'OMAXE',
#  'BEL',
#  'ASTERDM',
#  'NAVINFLUOR',
#  'SOLARA',
#  'AMARAJABAT',
#  'LINDEINDIA',
#  'HAVELLS',
#  'GESHIP',
#  'JKCEMENT',
#  'SIEMENS',
#  'PIDILITIND',
#  'SOLARINDS',
#  'IDFC',
#  'VENKEYS',
#  'ITC',
#  'TVSMOTOR',
#  'AMBUJACEM',
#  'MUTHOOTFIN',
#  'MASFIN',
#  'NLCINDIA',
#  'BHARTIARTL',
#  'ZYDUSWELL',
#  'FDC',
#  'CHOLAFIN',
#  'STAR',
#  'BOSCHLTD',
#  'LUPIN',
#  'YESBANK',
#  'OBEROIRLTY',
#  'EQUITAS',
#  'PSPPROJECT',
#  'VBL',
#  'PFIZER',
#  'VRLLOG',
#  'JCHAC',
#  'CHAMBLFERT',
#  'PFC',
#  'ASIANPAINT',
#  'SFL',
#  'WIPRO',
#  'ACC',
#  'ECLERX',
#  'TTKPRESTIG',
#  'JAGRAN',
#  'EMAMILTD',
#  'TIINDIA',
#  'VOLTAS',
#  'BIOCON',
#  'CIPLA',
#  'MCDOWELL-N',
#  'MCX',
#  'OFSS',
#  'ICICIGI',
#  'SUNTECK',
#  'BLUEDART',
#  'SBILIFE',
#  'ZENSARTECH',
#  'BHARATRAS',
#  'IOLCP',
#  'SHOPERSTOP',
#  'CHOLAHLDNG',
#  'FINEORG',
#  'GRASIM',
#  'INDOCO',
#  'COLPAL',
#  'COFORGE',
#  'CADILAHC',
#  'ALKEM',
#  'CROMPTON',
#  'SJVN',
#  'ADANIGAS',
#  'TORNTPHARM',
#  'CONCOR',
#  'TITAN',
#  'VIPIND',
#  'TECHM',
#  'UBL',
#  'NILKAMAL',
#  'GHCL',
#  'TEAMLEASE',
#  'AIAENG',
#  'AUROPHARMA',
#  'CENTURYPLY',
#  'VINATIORGA',
#  'GALAXYSURF',
#  'ABBOTINDIA',
#  'TRENT',
#  'CDSL',
#  'BERGEPAINT',
#  'TATAINVEST',
#  'AAVAS',
#  'ERIS',
#  'WHIRLPOOL',
#  'PNCINFRA',
#  'DIVISLAB',
#  'BRITANNIA',
#  'BALRAMCHIN',
#  'KRBL',
#  'JBCHEPHARM',
#  'SUNDRMFAST',
#  'ICICIPRULI',
#  'LAOPALA',
#  'APOLLOHOSP',
#  'IRCTC',
#  'GUJGASLTD',
#  'GEPIL',
#  'DABUR',
#  'CANFINHOME',
#  'PIIND',
#  'MINDTREE',
#  'TCS',
#  'CASTROLIND',
#  'BALKRISIND',
#  'PAGEIND',
#  'NAUKRI',
#  'EPL',
#  'GODREJCP',
#  'HDFCBANK',
#  'NESTLEIND',
#  'KSB',
#  'MINDAIND',
#  'PGHL',
#  'BAYERCROP',
#  'CARBORUNIV',
#  'CREDITACC',
#  'DEEPAKNTR',
#  'GLAXO',
#  'NESCO',
#  'HDFCLIFE',
#  'VSTIND',
#  'KNRCON',
#  'SUMICHEM',
#  'WESTLIFE',
#  'MAHLOG',
#  'PRAJIND',
#  'PGHH',
#  'ABB',
#  'INDIGO',
#  'MARICO',
#  'CERA',
#  'ENDURANCE',
#  'ESCORTS',
#  'SUPREMEIND',
#  'GODREJPROP',
#  'GODREJAGRO',
#  'IPCALAB',
#  'ABFRL',
#  'GODREJIND',
#  'SUVENPHAR',
#  'BLUESTARCO',
#  'THERMAX',
#  'ASHOKA',
#  'SKFINDIA',
#  'QUESS',
#  'CENTURYTEX',
#  'IFBIND',
#  'HINDUNILVR',
#  'HATHWAY',
#  'TCIEXP',
#  'CCL',
#  'KANSAINER',
#  'MPHASIS',
#  'PHOENIXLTD',
#  'DALBHARAT',
#  'GRINDWELL',
#  'VGUARD',
#  'AMBER',
#  'VTL',
#  'INOXLEISUR',
#  'DIXON',
#  'AJANTPHARM',
#  'WABCOINDIA',
#  'CUMMINSIND',
#  'CRISIL',
#  '3MINDIA',
#  'HONAUT',
#  'COROMANDEL',
#  'GILLETTE',
#  'REDINGTON',
#  'METROPOLIS',
#  'BRIGADE',
#  'APLAPOLLO']
